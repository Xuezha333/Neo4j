# %%
from py2neo import Node, Relationship, Graph
import json

# %% [markdown]
# ### 1. Connect to neo4j

# %%
graph = Graph('neo4j://localhost:7687', user="neo4j", password="Beijingdaxue123")
graph.run("MATCH (n) DETACH DELETE n")
graph
# Out:
# Graph('neo4j://localhost:7687')

# %% [markdown]
# ### 2. Import Data

# %%
# File names
data_files = ['./data/pred_test.json', './data/pred_train.json', './data/pred_val.json']

# %% [markdown]
# ### 3. Add data to graph

# %%
nodes = {}
for file_name in data_files:
    with open(file_name, 'r') as file:
        data = json.load(file)

    for dataset in data:
        for entry in dataset:
            if 'Entity' in entry:
                entity = entry['Entity']
                attributes = entry['Attributes']
                node_id = entry['Id']

                # Convert string representation of dictionary to actual dictionary
                # Merge node with unique constraint on 'name' attribute
                node = Node(entity, **attributes)
                graph.merge(node, entity, 'name')
                nodes[node_id] = node

                # Debugging: Print the created or merged node
                print(f"Created or merged node: {node}")

        for entry in dataset:
            if 'Relationship' in entry:
                rel_type = entry['Relationship']
                start_node_id = entry['StartNode']
                end_node_id = entry['EndNode']

                start_node = nodes[start_node_id]
                end_node = nodes[end_node_id]

                # Create relationship
                relationship = Relationship(start_node, rel_type, end_node)
                graph.create(relationship)

                # Debugging: Print the created relationship
                print(f"Created relationship: {relationship}")

    print("Nodes and relationships created successfully.")
# Out:
# Created or merged node: (_2623:media {name: 'news programs'})
# Created or merged node: (_2624:content {name: 'violence'})
# Created or merged node: (_0:medium {name: 'game'})
# Created or merged node: (_1:group {name: 'players'})
# Created relationship: (violence)-[:isRecivedby {}]->(players)
# Created relationship: (game)-[:isDisplayedvia {}]->(news programs)
# Created relationship: (game)-[:isDistributedto {}]->(players)
# Created relationship: (players)-[:isInformedby {}]->(news programs)
# Created or merged node: (_2:medium {name: 'article'})
# Created or merged node: (_3:group {name: 'authors'})
# Created or merged node: (_4:medium {name: 'technology'})
# Created or merged node: (_5:group {name: 'small pharmacy chains'})
# Created relationship: (article)-[:isDistributedto {}]->(authors)
# Created relationship: (article)-[:isDistributedto {}]->(small pharmacy chains)
# Created relationship: (technology)-[:isDistributedto {}]->(authors)
# Created relationship: (technology)-[:isDistributedto {}]->(small pharmacy chains)
# Created or merged node: (_6:media {name: 'magazine'})
# Created or merged node: (_7:group {name: 'athletes'})
# Created or merged node: (_8:group {name: 'soldiers'})
# Created relationship: (athletes)-[:isInformedby {}]->(magazine)
# Created relationship: (soldiers)-[:isInformedby {}]->(magazine)
# Created or merged node: (_9:medium {name: 'volume'})
# Created or merged node: (_10:group {name: 'contemporary political debate'})
# Created relationship: (volume)-[:isDistributedto {}]->(contemporary political debate)
# Created or merged node: (_11:group {name: 'audience'})
# Created or merged node: (_12:media {name: 'television'})
# Created or merged node: (_13:content {name: 'democracy of culture'})
# Created or merged node: (_14:group {name: 'english accent'})
# Created relationship: (audience)-[:isInformedby {}]->(television)
# Created relationship: (democracy of culture)-[:isRecivedby {}]->(audience)
# Created relationship: (democracy of culture)-[:isRecivedby {}]->(english accent)
# Created relationship: (english accent)-[:isInformedby {}]->(television)
# Created or merged node: (_15:medium {name: 'documents'})
# Created or merged node: (_16:group {name: 'enron'})
# Created relationship: (documents)-[:isDistributedto {}]->(enron)
# Created or merged node: (_17:content {name: 'history'})
# Created or merged node: (_18:medium {name: 'prose'})
# Created or merged node: (_19:content {name: 'narrative'})
# Created or merged node: (_17:content {name: 'history'})
# Created or merged node: (_20:group {name: 'great people'})
# Created relationship: (history)-[:isRecivedby {}]->(great people)
# Created relationship: (prose)-[:isDistributedto {}]->(great people)
# Created relationship: (narrative)-[:isRecivedby {}]->(great people)
# Created relationship: (history)-[:isRecivedby {}]->(great people)
# Created or merged node: (_21:medium {name: 'roundtables'})
# Created or merged node: (_22:content {name: 'keywords'})
# Created or merged node: (_23:group {name: 'students'})
# Created relationship: (roundtables)-[:isDistributedto {}]->(students)
# Created relationship: (keywords)-[:isRecivedby {}]->(students)
# Created or merged node: (_24:medium {name: 'media coverage'})
# Created or merged node: (_25:group {name: 'catholic church'})
# Created relationship: (media coverage)-[:isDistributedto {}]->(catholic church)
# Created or merged node: (_26:medium {name: 'investigations'})
# Created or merged node: (_27:group {name: 'poor'})
# Created relationship: (investigations)-[:isDistributedto {}]->(poor)
# Created or merged node: (_28:medium {name: 'book'})
# Created or merged node: (_29:group {name: 'muhammad'})
# Created relationship: (book)-[:isDistributedto {}]->(muhammad)
# Created or merged node: (_30:medium {name: 'film'})
# Created or merged node: (_31:group {name: 'cadaver'})
# Created relationship: (film)-[:isDistributedto {}]->(cadaver)
# Created or merged node: (_2:medium {name: 'article'})
# Created or merged node: (_32:group {name: 'pre-school children'})
# Created or merged node: (_33:group {name: 'parents'})
# Created or merged node: (_34:group {name: 'early years workers'})
# Created relationship: (article)-[:isDistributedto {}]->(pre-school children)
# Created relationship: (article)-[:isDistributedto {}]->(parents)
# Created relationship: (article)-[:isDistributedto {}]->(early years workers)
# Created or merged node: (_35:medium {name: 'research articles'})
# Created or merged node: (_36:content {name: 'health promotion'})
# Created or merged node: (_37:group {name: 'retirement'})
# Created relationship: (research articles)-[:isDistributedto {}]->(retirement)
# Created relationship: (health promotion)-[:isRecivedby {}]->(retirement)
# Created or merged node: (_38:media {name: 'desperados'})
# Created or merged node: (_39:media {name: "cbbc children 's drama series"})
# Created or merged node: (_40:group {name: 'wheelchair basketball team'})
# Created relationship: (wheelchair basketball team)-[:isInformedby {}]->(desperados)
# Created relationship: (wheelchair basketball team)-[:isInformedby {}]->(cbbc children 's drama series)
# Created or merged node: (_41:medium {name: 'document'})
# Created or merged node: (_42:group {name: 'arts'})
# Created or merged node: (_42:group {name: 'arts'})
# Created relationship: (document)-[:isDistributedto {}]->(arts)
# Created relationship: (document)-[:isDistributedto {}]->(arts)
# Created or merged node: (_43:media {name: 'newspaper advertising'})
# Created or merged node: (_44:group {name: 'customers'})
# Created or merged node: (_45:content {name: 'selections'})
# Created relationship: (customers)-[:isInformedby {}]->(newspaper advertising)
# Created relationship: (selections)-[:isRecivedby {}]->(customers)
# Created or merged node: (_46:media {name: 'newsletter'})
# Created or merged node: (_47:group {name: 'families'})
# Created relationship: (families)-[:isInformedby {}]->(newsletter)
# Created or merged node: (_48:content {name: 'information'})
# Created or merged node: (_49:group {name: 'employees'})
# Created relationship: (information)-[:isRecivedby {}]->(employees)
# Created or merged node: (_28:medium {name: 'book'})
# Created or merged node: (_50:group {name: 'us'})
# Created or merged node: (_51:group {name: 'yemen'})
# Created relationship: (book)-[:isDistributedto {}]->(us)
# Created relationship: (book)-[:isDistributedto {}]->(yemen)
# Created or merged node: (_52:medium {name: 'fairy tale'})
# Created or merged node: (_53:group {name: 'giant'})
# Created relationship: (fairy tale)-[:isDistributedto {}]->(giant)
# Created or merged node: (_54:medium {name: 'tract'})
# Created or merged node: (_55:group {name: 'western liturgical practices'})
# Created relationship: (tract)-[:isDistributedto {}]->(western liturgical practices)
# Created or merged node: (_56:content {name: 'story'})
# Created or merged node: (_57:group {name: 'boy'})
# Created or merged node: (_58:group {name: 'young woman'})
# Created relationship: (story)-[:isRecivedby {}]->(boy)
# Created relationship: (story)-[:isRecivedby {}]->(young woman)
# Created or merged node: (_59:media {name: 'documentary film'})
# Created or merged node: (_60:group {name: 'jamaican economy'})
# Created relationship: (jamaican economy)-[:isInformedby {}]->(documentary film)
# Created or merged node: (_61:medium {name: 'chapter'})
# Created or merged node: (_62:group {name: 'pe funds'})
# Created relationship: (chapter)-[:isDistributedto {}]->(pe funds)
# Created or merged node: (_63:medium {name: 'bulletin'})
# Created or merged node: (_64:group {name: 'key persons'})
# Created or merged node: (_65:group {name: 'opinion leaders'})
# Created relationship: (bulletin)-[:isDistributedto {}]->(key persons)
# Created relationship: (bulletin)-[:isDistributedto {}]->(opinion leaders)
# Created or merged node: (_66:medium {name: 'flat panel painting'})
# Created or merged node: (_67:group {name: 'holy being'})
# Created relationship: (flat panel painting)-[:isDistributedto {}]->(holy being)
# Created or merged node: (_68:media {name: 'blog'})
# Created or merged node: (_69:medium {name: 'news'})
# Created or merged node: (_70:group {name: 'science'})
# Created or merged node: (_71:group {name: 'religion'})
# Created relationship: (news)-[:isDisplayedvia {}]->(blog)
# Created relationship: (news)-[:isDistributedto {}]->(science)
# Created relationship: (news)-[:isDistributedto {}]->(religion)
# Created relationship: (science)-[:isInformedby {}]->(blog)
# Created relationship: (religion)-[:isInformedby {}]->(blog)
# Created or merged node: (_72:media {name: 'weekly economic publication'})
# Created or merged node: (_73:group {name: 'financial'})
# Created or merged node: (_74:group {name: 'commercial'})
# Created or merged node: (_75:content {name: 'industrial developments'})
# Created relationship: (financial)-[:isInformedby {}]->(weekly economic publication)
# Created relationship: (commercial)-[:isInformedby {}]->(weekly economic publication)
# Created relationship: (industrial developments)-[:isRecivedby {}]->(financial)
# Created relationship: (industrial developments)-[:isRecivedby {}]->(commercial)
# Created or merged node: (_76:medium {name: 'exhibition'})
# Created or merged node: (_77:group {name: 'american people'})
# Created or merged node: (_78:group {name: 'european explorers'})
# Created or merged node: (_79:group {name: 'conquerors'})
# Created or merged node: (_80:group {name: 'settlers'})
# Created relationship: (exhibition)-[:isDistributedto {}]->(american people)
# Created relationship: (exhibition)-[:isDistributedto {}]->(european explorers)
# Created relationship: (exhibition)-[:isDistributedto {}]->(conquerors)
# Created relationship: (exhibition)-[:isDistributedto {}]->(settlers)
# Created or merged node: (_28:medium {name: 'book'})
# Created or merged node: (_81:group {name: 'human rights'})
# Created or merged node: (_82:group {name: 'politics'})
# Created relationship: (book)-[:isDistributedto {}]->(human rights)
# Created relationship: (book)-[:isDistributedto {}]->(politics)
# Created or merged node: (_83:group {name: 'class'})
# Created or merged node: (_84:medium {name: 'writing'})
# Created or merged node: (_84:medium {name: 'writing'})
# Created relationship: (writing)-[:isDistributedto {}]->(class)
# Created relationship: (writing)-[:isDistributedto {}]->(class)
# Created or merged node: (_85:medium {name: 'books'})
# Created or merged node: (_86:group {name: 'birds'})
# Created relationship: (books)-[:isDistributedto {}]->(birds)
# Created or merged node: (_87:content {name: 'document'})
# Created or merged node: (_88:group {name: 'witness'})
# Created relationship: (document)-[:isRecivedby {}]->(witness)
# Created or merged node: (_89:content {name: 'topics'})
# Created or merged node: (_90:group {name: 'speakers'})
# Created relationship: (topics)-[:isRecivedby {}]->(speakers)
# Created or merged node: (_91:media {name: 'article'})
# Created or merged node: (_92:medium {name: 'music'})
# Created relationship: (music)-[:isDisplayedvia {}]->(article)
# Created or merged node: (_93:media {name: 'quarterly magazine'})
# Created or merged node: (_94:group {name: 'political'})
# Created or merged node: (_95:group {name: 'economic'})
# Created or merged node: (_96:group {name: 'social'})
# Created or merged node: (_97:group {name: 'cultural'})
# Created or merged node: (_98:group {name: 'sporting'})
# Created relationship: (political)-[:isInformedby {}]->(quarterly magazine)
# Created relationship: (economic)-[:isInformedby {}]->(quarterly magazine)
# Created relationship: (social)-[:isInformedby {}]->(quarterly magazine)
# Created relationship: (cultural)-[:isInformedby {}]->(quarterly magazine)
# Created relationship: (sporting)-[:isInformedby {}]->(quarterly magazine)
# Created or merged node: (_28:medium {name: 'book'})
# Created or merged node: (_99:group {name: 'teaching'})
# Created or merged node: (_100:group {name: 'learning'})
# Created relationship: (book)-[:isDistributedto {}]->(teaching)
# Created relationship: (book)-[:isDistributedto {}]->(learning)
# Created or merged node: (_28:medium {name: 'book'})
# Created or merged node: (_101:content {name: 'social history'})
# Created or merged node: (_23:group {name: 'students'})
# Created or merged node: (_102:group {name: 'faculty'})
# Created relationship: (book)-[:isDistributedto {}]->(students)
# Created relationship: (book)-[:isDistributedto {}]->(faculty)
# Created relationship: (social history)-[:isRecivedby {}]->(students)
# Created relationship: (social history)-[:isRecivedby {}]->(faculty)
# Created or merged node: (_103:content {name: 'works'})
# Created or merged node: (_104:group {name: 'epistemology'})
# Created or merged node: (_71:group {name: 'religion'})
# Created or merged node: (_105:group {name: 'law'})
# Created or merged node: (_106:group {name: 'history'})
# Created relationship: (works)-[:isRecivedby {}]->(epistemology)
# Created relationship: (works)-[:isRecivedby {}]->(religion)
# Created relationship: (works)-[:isRecivedby {}]->(law)
# Created relationship: (works)-[:isRecivedby {}]->(history)
# Created or merged node: (_107:group {name: 'parent'})
# Created or merged node: (_108:content {name: 'story-relevant questions'})
# Created relationship: (story-relevant questions)-[:isRecivedby {}]->(parent)
# Created or merged node: (_109:content {name: 'letter'})
# Created or merged node: (_110:group {name: 'dispute'})
# Created relationship: (letter)-[:isRecivedby {}]->(dispute)
# Created or merged node: (_111:medium {name: 'sketch'})
# Created or merged node: (_112:group {name: 'species'})
# Created relationship: (sketch)-[:isDistributedto {}]->(species)
# Created or merged node: (_113:content {name: 'guide'})
# Created or merged node: (_114:content {name: 'issues'})
# Created or merged node: (_115:group {name: 'junior reporter'})
# Created relationship: (guide)-[:isRecivedby {}]->(junior reporter)
# Created relationship: (issues)-[:isRecivedby {}]->(junior reporter)
# Created or merged node: (_116:content {name: 'jazz harmony'})
# Created or merged node: (_117:group {name: 'jazz pianist'})
# Created relationship: (jazz harmony)-[:isRecivedby {}]->(jazz pianist)
# Created or merged node: (_118:medium {name: 'files'})
# Created or merged node: (_119:group {name: 'yoshida'})
# Created relationship: (files)-[:isDistributedto {}]->(yoshida)
# Created or merged node: (_120:medium {name: 'feminist science fiction'})
# Created or merged node: (_121:group {name: 'women'})
# Created relationship: (feminist science fiction)-[:isDistributedto {}]->(women)
# Created or merged node: (_122:content {name: 'tricks'})
# Created or merged node: (_123:group {name: 'orville'})
# Created or merged node: (_124:group {name: 'people'})
# Created relationship: (tricks)-[:isRecivedby {}]->(orville)
# Created relationship: (tricks)-[:isRecivedby {}]->(people)
# Created or merged node: (_125:media {name: 'book'})
# Created or merged node: (_126:group {name: 'health care provider'})
# Created relationship: (health care provider)-[:isInformedby {}]->(book)
# Created or merged node: (_127:medium {name: 'play'})
# Created or merged node: (_128:group {name: 'courageous'})
# Created or merged node: (_129:group {name: 'noble man'})
# Created relationship: (play)-[:isDistributedto {}]->(courageous)
# Created relationship: (play)-[:isDistributedto {}]->(noble man)
# Created or merged node: (_130:group {name: 'rural community'})
# Created or merged node: (_131:medium {name: 'stories'})
# Created relationship: (stories)-[:isDistributedto {}]->(rural community)
# Created or merged node: (_2:medium {name: 'article'})
# Created or merged node: (_132:group {name: 'baseball player'})
# Created or merged node: (_133:medium {name: 'baseball matches'})
# Created relationship: (article)-[:isDistributedto {}]->(baseball player)
# Created relationship: (baseball matches)-[:isDistributedto {}]->(baseball player)
# Created or merged node: (_113:content {name: 'guide'})
# Created or merged node: (_134:group {name: 'thinkers'})
# Created relationship: (guide)-[:isRecivedby {}]->(thinkers)
# Created or merged node: (_30:medium {name: 'film'})
# Created or merged node: (_83:group {name: 'class'})
# Created or merged node: (_135:group {name: 'severine'})
# Created relationship: (film)-[:isDistributedto {}]->(class)
# Created relationship: (film)-[:isDistributedto {}]->(severine)
# Created or merged node: (_136:medium {name: 'classroom discussion'})
# Created or merged node: (_137:group {name: 'candidates'})
# Created relationship: (classroom discussion)-[:isDistributedto {}]->(candidates)
# Created or merged node: (_15:medium {name: 'documents'})
# Created or merged node: (_138:medium {name: 'literature'})
# Created or merged node: (_139:group {name: 'worker'})
# Created or merged node: (_140:content {name: 'hazards'})
# Created relationship: (documents)-[:isDistributedto {}]->(worker)
# Created relationship: (literature)-[:isDistributedto {}]->(worker)
# Created relationship: (hazards)-[:isRecivedby {}]->(worker)
# Created or merged node: (_141:media {name: 'online journal'})
# Created or merged node: (_142:group {name: 'sports'})
# Created or merged node: (_143:group {name: 'youth'})
# Created or merged node: (_144:group {name: 'society'})
# Created relationship: (sports)-[:isInformedby {}]->(online journal)
# Created relationship: (youth)-[:isInformedby {}]->(online journal)
# Created relationship: (society)-[:isInformedby {}]->(online journal)
# Created or merged node: (_145:media {name: 'album'})
# Created or merged node: (_146:group {name: 'wolf'})
# Created or merged node: (_147:content {name: 'song'})
# Created relationship: (wolf)-[:isInformedby {}]->(album)
# Created relationship: (song)-[:isRecivedby {}]->(wolf)
# Created or merged node: (_148:media {name: 'opera'})
# Created or merged node: (_149:group {name: 'characters'})
# Created or merged node: (_150:content {name: 'storyline'})
# Created relationship: (characters)-[:isInformedby {}]->(opera)
# Created relationship: (storyline)-[:isRecivedby {}]->(characters)
# Created or merged node: (_28:medium {name: 'book'})
# Created or merged node: (_71:group {name: 'religion'})
# Created or merged node: (_151:group {name: 'dutch emigration'})
# Created relationship: (book)-[:isDistributedto {}]->(religion)
# Created relationship: (book)-[:isDistributedto {}]->(dutch emigration)
# Created or merged node: (_152:content {name: 'fable'})
# Created or merged node: (_153:group {name: 'education'})
# Created relationship: (fable)-[:isRecivedby {}]->(education)
# Created or merged node: (_154:medium {name: 'notification'})
# Created or merged node: (_155:group {name: 'plants'})
# Created or merged node: (_156:group {name: 'plant pests'})
# Created or merged node: (_157:group {name: 'carriers'})
# Created relationship: (notification)-[:isDistributedto {}]->(plants)
# Created relationship: (notification)-[:isDistributedto {}]->(plant pests)
# Created relationship: (notification)-[:isDistributedto {}]->(carriers)
# Created or merged node: (_158:content {name: 'message'})
# Created or merged node: (_159:group {name: 'religious social structure'})
# Created relationship: (message)-[:isRecivedby {}]->(religious social structure)
# Created or merged node: (_160:medium {name: 'lyrics'})
# Created or merged node: (_161:group {name: 'boys'})
# Created or merged node: (_162:group {name: 'girls'})
# Created relationship: (lyrics)-[:isDistributedto {}]->(boys)
# Created relationship: (lyrics)-[:isDistributedto {}]->(girls)
# Created or merged node: (_163:media {name: 'show'})
# Created or merged node: (_164:content {name: 'hot-button topic'})
# Created or merged node: (_165:group {name: 'm & a experts'})
# Created relationship: (hot-button topic)-[:isRecivedby {}]->(m & a experts)
# Created relationship: (m & a experts)-[:isInformedby {}]->(show)
# Created or merged node: (_141:media {name: 'online journal'})
# Created or merged node: (_166:medium {name: 'media criticism'})
# Created or merged node: (_71:group {name: 'religion'})
# Created or merged node: (_167:media {name: 'press'})
# Created relationship: (media criticism)-[:isDisplayedvia {}]->(online journal)
# Created relationship: (media criticism)-[:isDistributedto {}]->(religion)
# Created relationship: (media criticism)-[:isDisplayedvia {}]->(press)
# Created relationship: (religion)-[:isInformedby {}]->(online journal)
# Created relationship: (religion)-[:isInformedby {}]->(press)
# Created or merged node: (_168:medium {name: 'weekly magazine'})
# Created or merged node: (_169:group {name: 'culture'})
# Created or merged node: (_82:group {name: 'politics'})
# Created or merged node: (_170:content {name: 'style'})
# Created relationship: (weekly magazine)-[:isDistributedto {}]->(culture)
# Created relationship: (weekly magazine)-[:isDistributedto {}]->(politics)
# Created relationship: (style)-[:isRecivedby {}]->(culture)
# Created relationship: (style)-[:isRecivedby {}]->(politics)
# Created or merged node: (_171:content {name: 'speech'})
# Created or merged node: (_172:content {name: 'conversation'})
# Created or merged node: (_173:group {name: 'daughter'})
# Created relationship: (speech)-[:isRecivedby {}]->(daughter)
# Created relationship: (conversation)-[:isRecivedby {}]->(daughter)
# Created or merged node: (_174:group {name: 'family'})
# Created or merged node: (_175:content {name: 'picture'})
# Created relationship: (picture)-[:isRecivedby {}]->(family)
# Created or merged node: (_176:group {name: 'ubc graduate student'})
# Created or merged node: (_124:group {name: 'people'})
# Created or merged node: (_177:content {name: 'colour'})
# Created or merged node: (_178:media {name: 'digital photos'})
# Created relationship: (ubc graduate student)-[:isInformedby {}]->(digital photos)
# Created relationship: (people)-[:isInformedby {}]->(digital photos)
# Created relationship: (colour)-[:isRecivedby {}]->(ubc graduate student)
# Created relationship: (colour)-[:isRecivedby {}]->(people)
# Created or merged node: (_179:content {name: 'list'})
# Created or merged node: (_180:group {name: 'philosopher'})
# Created relationship: (list)-[:isRecivedby {}]->(philosopher)
# Created or merged node: (_181:group {name: 'grandfather'})
# Created or merged node: (_182:group {name: 'ancestors'})
# Created or merged node: (_183:content {name: 'family story'})
# Created relationship: (family story)-[:isRecivedby {}]->(grandfather)
# Created relationship: (family story)-[:isRecivedby {}]->(ancestors)
# Created or merged node: (_184:group {name: 'writer'})
# Created or merged node: (_185:media {name: 'bbc television series'})
# Created relationship: (writer)-[:isInformedby {}]->(bbc television series)
# Created or merged node: (_186:group {name: 'musician'})
# Created or merged node: (_187:group {name: 'suicide bombers'})
# Created or merged node: (_188:medium {name: 'anti-terrorism legislation'})
# Created relationship: (anti-terrorism legislation)-[:isDistributedto {}]->(musician)
# Created relationship: (anti-terrorism legislation)-[:isDistributedto {}]->(suicide bombers)
# Created or merged node: (_184:group {name: 'writer'})
# Created or merged node: (_189:content {name: 'storyboard'})
# Created relationship: (storyboard)-[:isRecivedby {}]->(writer)
# Created or merged node: (_23:group {name: 'students'})
# Created or merged node: (_190:medium {name: 'blackboard'})
# Created or merged node: (_191:content {name: 'drawing'})
# Created relationship: (blackboard)-[:isDistributedto {}]->(students)
# Created relationship: (drawing)-[:isRecivedby {}]->(students)
# Created or merged node: (_192:group {name: 'ghostwriters'})
# Created or merged node: (_193:content {name: 'template'})
# Created or merged node: (_194:content {name: 'fictional universe'})
# Created relationship: (template)-[:isRecivedby {}]->(ghostwriters)
# Created relationship: (fictional universe)-[:isRecivedby {}]->(ghostwriters)
# Created or merged node: (_195:medium {name: 'pencil'})
# Created or merged node: (_196:medium {name: 'graphite'})
# Created or merged node: (_197:group {name: 'painter'})
# Created relationship: (pencil)-[:isDistributedto {}]->(painter)
# Created relationship: (graphite)-[:isDistributedto {}]->(painter)
# Created or merged node: (_198:group {name: 'lagravenese'})
# Created or merged node: (_56:content {name: 'story'})
# Created relationship: (story)-[:isRecivedby {}]->(lagravenese)
# Created or merged node: (_147:content {name: 'song'})
# Created or merged node: (_199:group {name: 'hip-hop superstar'})
# Created relationship: (song)-[:isRecivedby {}]->(hip-hop superstar)
# Created or merged node: (_200:group {name: 'soldier'})
# Created or merged node: (_158:content {name: 'message'})
# Created or merged node: (_201:media {name: 'website'})
# Created relationship: (soldier)-[:isInformedby {}]->(website)
# Created relationship: (message)-[:isRecivedby {}]->(soldier)
# Created or merged node: (_202:group {name: 'duo'})
# Created or merged node: (_203:content {name: 'songs'})
# Created or merged node: (_204:medium {name: 'album'})
# Created relationship: (songs)-[:isRecivedby {}]->(duo)
# Created relationship: (album)-[:isDistributedto {}]->(duo)
# Created or merged node: (_205:group {name: 'producer'})
# Created or merged node: (_206:media {name: 'paid tv programs'})
# Created relationship: (producer)-[:isInformedby {}]->(paid tv programs)
# Created or merged node: (_207:content {name: 'hit list'})
# Created or merged node: (_208:group {name: 'ten people'})
# Created relationship: (hit list)-[:isRecivedby {}]->(ten people)
# Created or merged node: (_23:group {name: 'students'})
# Created or merged node: (_209:medium {name: 'wiki'})
# Created or merged node: (_210:content {name: 'topic'})
# Created relationship: (wiki)-[:isDistributedto {}]->(students)
# Created relationship: (topic)-[:isRecivedby {}]->(students)
# Created or merged node: (_211:group {name: 'official'})
# Created or merged node: (_212:group {name: 'senior officials'})
# Created or merged node: (_213:medium {name: 'september dossier'})
# Created relationship: (september dossier)-[:isDistributedto {}]->(official)
# Created relationship: (september dossier)-[:isDistributedto {}]->(senior officials)
# Created or merged node: (_214:group {name: 'employee'})
# Created or merged node: (_215:content {name: 'negative comment'})
# Created relationship: (negative comment)-[:isRecivedby {}]->(employee)
# Created or merged node: (_216:group {name: 'researchers'})
# Created or merged node: (_217:medium {name: 'report'})
# Created relationship: (report)-[:isDistributedto {}]->(researchers)
# Created or merged node: (_218:group {name: 'americans'})
# Created or merged node: (_219:media {name: 'online video'})
# Created relationship: (americans)-[:isInformedby {}]->(online video)
# Created or merged node: (_220:group {name: 'poet'})
# Created or merged node: (_221:content {name: 'oeuvre'})
# Created or merged node: (_18:medium {name: 'prose'})
# Created or merged node: (_222:content {name: 'poems'})
# Created relationship: (oeuvre)-[:isRecivedby {}]->(poet)
# Created relationship: (prose)-[:isDistributedto {}]->(poet)
# Created relationship: (poems)-[:isRecivedby {}]->(poet)
# Created or merged node: (_223:group {name: 'creator'})
# Created or merged node: (_224:medium {name: 'computer game'})
# Created relationship: (computer game)-[:isDistributedto {}]->(creator)
# Created or merged node: (_225:group {name: 'physicist'})
# Created or merged node: (_226:content {name: 'black hole'})
# Created or merged node: (_227:medium {name: 'autobiography'})
# Created relationship: (black hole)-[:isRecivedby {}]->(physicist)
# Created relationship: (autobiography)-[:isDistributedto {}]->(physicist)
# Created or merged node: (_228:medium {name: 'sculpture'})
# Created or merged node: (_229:group {name: 'artist'})
# Created relationship: (sculpture)-[:isDistributedto {}]->(artist)
# Created or merged node: (_230:group {name: 'golfer'})
# Created or merged node: (_201:media {name: 'website'})
# Created or merged node: (_174:group {name: 'family'})
# Created relationship: (golfer)-[:isInformedby {}]->(website)
# Created relationship: (family)-[:isInformedby {}]->(website)
# Created or merged node: (_231:content {name: 'props'})
# Created or merged node: (_232:group {name: 'person'})
# Created relationship: (props)-[:isRecivedby {}]->(person)
# Created or merged node: (_233:group {name: 'passenger'})
# Created or merged node: (_234:medium {name: 'photograph'})
# Created relationship: (photograph)-[:isDistributedto {}]->(passenger)
# Created or merged node: (_235:medium {name: 'blog'})
# Created or merged node: (_236:medium {name: 'style rookie'})
# Created or merged node: (_237:group {name: 'designers'})
# Created relationship: (blog)-[:isDistributedto {}]->(designers)
# Created relationship: (style rookie)-[:isDistributedto {}]->(designers)
# Created or merged node: (_222:content {name: 'poems'})
# Created or merged node: (_238:group {name: 'expressionist poet'})
# Created or merged node: (_239:group {name: 'trakl'})
# Created relationship: (poems)-[:isRecivedby {}]->(expressionist poet)
# Created relationship: (poems)-[:isRecivedby {}]->(trakl)
# Created or merged node: (_240:content {name: 'work'})
# Created or merged node: (_220:group {name: 'poet'})
# Created or merged node: (_241:content {name: 'sequel'})
# Created relationship: (work)-[:isRecivedby {}]->(poet)
# Created relationship: (sequel)-[:isRecivedby {}]->(poet)
# Created or merged node: (_242:group {name: 'designer'})
# Created or merged node: (_243:content {name: 'sets'})
# Created relationship: (sets)-[:isRecivedby {}]->(designer)
# Created or merged node: (_244:group {name: 'researcher'})
# Created or merged node: (_245:medium {name: 'interview'})
# Created relationship: (interview)-[:isDistributedto {}]->(researcher)
# Created or merged node: (_246:group {name: 'author'})
# Created or merged node: (_247:content {name: 'short book'})
# Created relationship: (short book)-[:isRecivedby {}]->(author)
# Created or merged node: (_248:group {name: 'model maker'})
# Created or merged node: (_249:group {name: 'craftsperson'})
# Created or merged node: (_250:content {name: '3-dimensional representation'})
# Created or merged node: (_251:content {name: 'design'})
# Created or merged node: (_252:content {name: 'concept'})
# Created relationship: (3-dimensional representation)-[:isRecivedby {}]->(model maker)
# Created relationship: (3-dimensional representation)-[:isRecivedby {}]->(craftsperson)
# Created relationship: (design)-[:isRecivedby {}]->(model maker)
# Created relationship: (design)-[:isRecivedby {}]->(craftsperson)
# Created relationship: (concept)-[:isRecivedby {}]->(model maker)
# Created relationship: (concept)-[:isRecivedby {}]->(craftsperson)
# Created or merged node: (_253:content {name: 'preface'})
# Created or merged node: (_254:content {name: 'introduction'})
# Created or merged node: (_255:content {name: 'book'})
# Created or merged node: (_246:group {name: 'author'})
# Created or merged node: (_255:content {name: 'book'})
# Created relationship: (preface)-[:isRecivedby {}]->(author)
# Created relationship: (introduction)-[:isRecivedby {}]->(author)
# Created relationship: (book)-[:isRecivedby {}]->(author)
# Created relationship: (book)-[:isRecivedby {}]->(author)
# Created or merged node: (_256:group {name: 'director'})
# Created or merged node: (_257:medium {name: 'footage'})
# Created relationship: (footage)-[:isDistributedto {}]->(director)
# Created or merged node: (_258:group {name: 'school master'})
# Created or merged node: (_259:content {name: 'lesson'})
# Created or merged node: (_260:content {name: 'stick'})
# Created relationship: (lesson)-[:isRecivedby {}]->(school master)
# Created relationship: (stick)-[:isRecivedby {}]->(school master)
# Created or merged node: (_261:group {name: 'witch'})
# Created or merged node: (_262:medium {name: 'magic'})
# Created relationship: (magic)-[:isDistributedto {}]->(witch)
# Created or merged node: (_263:group {name: 'cartomancers'})
# Created or merged node: (_264:medium {name: 'divination'})
# Created relationship: (divination)-[:isDistributedto {}]->(cartomancers)
# Created or merged node: (_265:content {name: 'photo'})
# Created or merged node: (_266:medium {name: 'page'})
# Created or merged node: (_267:group {name: 'pilot'})
# Created relationship: (photo)-[:isRecivedby {}]->(pilot)
# Created relationship: (page)-[:isDistributedto {}]->(pilot)
# Created or merged node: (_268:group {name: 'playwright'})
# Created or merged node: (_269:medium {name: 'stage directions'})
# Created relationship: (stage directions)-[:isDistributedto {}]->(playwright)
# Created or merged node: (_270:group {name: 'punks'})
# Created or merged node: (_271:content {name: 'objects'})
# Created relationship: (objects)-[:isRecivedby {}]->(punks)
# Created or merged node: (_244:group {name: 'researcher'})
# Created or merged node: (_272:content {name: 'data'})
# Created relationship: (data)-[:isRecivedby {}]->(researcher)
# Created or merged node: (_272:content {name: 'data'})
# Created or merged node: (_273:group {name: 'staff'})
# Created relationship: (data)-[:isRecivedby {}]->(staff)
# Created or merged node: (_274:content {name: 'aphorisms'})
# Created or merged node: (_275:group {name: 'biographer'})
# Created or merged node: (_276:group {name: 'personality'})
# Created or merged node: (_277:content {name: 'minutiae'})
# Created relationship: (aphorisms)-[:isRecivedby {}]->(biographer)
# Created relationship: (aphorisms)-[:isRecivedby {}]->(personality)
# Created relationship: (minutiae)-[:isRecivedby {}]->(biographer)
# Created relationship: (minutiae)-[:isRecivedby {}]->(personality)
# Created or merged node: (_278:group {name: 'managers'})
# Created or merged node: (_279:medium {name: 'spreadsheets'})
# Created relationship: (spreadsheets)-[:isDistributedto {}]->(managers)
# Created or merged node: (_280:group {name: 'student'})
# Created or merged node: (_281:media {name: 'isa website'})
# Created relationship: (student)-[:isInformedby {}]->(isa website)
# Created or merged node: (_280:group {name: 'student'})
# Created or merged node: (_282:medium {name: 'telephone'})
# Created relationship: (telephone)-[:isDistributedto {}]->(student)
# Created or merged node: (_229:group {name: 'artist'})
# Created or merged node: (_283:medium {name: 'colouring crayons'})
# Created relationship: (colouring crayons)-[:isDistributedto {}]->(artist)
# Created or merged node: (_284:content {name: 'allegory'})
# Created or merged node: (_285:medium {name: 'flemish proverb'})
# Created or merged node: (_286:group {name: 'merchant'})
# Created relationship: (allegory)-[:isRecivedby {}]->(merchant)
# Created relationship: (flemish proverb)-[:isDistributedto {}]->(merchant)
# Created or merged node: (_287:medium {name: 'art'})
# Created or merged node: (_288:group {name: 'viewers'})
# Created relationship: (art)-[:isDistributedto {}]->(viewers)
# Created or merged node: (_229:group {name: 'artist'})
# Created or merged node: (_289:medium {name: 'pointer'})
# Created or merged node: (_290:medium {name: 'pantograph'})
# Created or merged node: (_291:content {name: 'image'})
# Created or merged node: (_195:medium {name: 'pencil'})
# Created or merged node: (_291:content {name: 'image'})
# Created relationship: (pointer)-[:isDistributedto {}]->(artist)
# Created relationship: (pantograph)-[:isDistributedto {}]->(artist)
# Created relationship: (image)-[:isRecivedby {}]->(artist)
# Created relationship: (pencil)-[:isDistributedto {}]->(artist)
# Created relationship: (image)-[:isRecivedby {}]->(artist)
# Created or merged node: (_292:medium {name: 'national discourse'})
# Created or merged node: (_293:group {name: 'british sailor'})
# Created or merged node: (_294:group {name: 'french seaman'})
# Created relationship: (national discourse)-[:isDistributedto {}]->(british sailor)
# Created relationship: (national discourse)-[:isDistributedto {}]->(french seaman)
# Created or merged node: (_295:group {name: 'children'})
# Created or merged node: (_296:group {name: 'fitter'})
# Created or merged node: (_297:medium {name: 'state of the art'})
# Created relationship: (state of the art)-[:isDistributedto {}]->(children)
# Created relationship: (state of the art)-[:isDistributedto {}]->(fitter)
# Created or merged node: (_298:group {name: 'scientists'})
# Created or merged node: (_92:medium {name: 'music'})
# Created or merged node: (_299:content {name: 'messages'})
# Created or merged node: (_300:group {name: 'public'})
# Created relationship: (music)-[:isDistributedto {}]->(scientists)
# Created relationship: (music)-[:isDistributedto {}]->(public)
# Created relationship: (messages)-[:isRecivedby {}]->(scientists)
# Created relationship: (messages)-[:isRecivedby {}]->(public)
# Created or merged node: (_301:medium {name: 'photo'})
# Created or merged node: (_139:group {name: 'worker'})
# Created relationship: (photo)-[:isDistributedto {}]->(worker)
# Created or merged node: (_302:group {name: 'parties'})
# Created or merged node: (_282:medium {name: 'telephone'})
# Created or merged node: (_232:group {name: 'person'})
# Created relationship: (telephone)-[:isDistributedto {}]->(parties)
# Created relationship: (telephone)-[:isDistributedto {}]->(person)
# Created or merged node: (_303:group {name: 'user'})
# Created or merged node: (_304:content {name: 'spatio-temporal information'})
# Created relationship: (spatio-temporal information)-[:isRecivedby {}]->(user)
# Created or merged node: (_305:group {name: 'teacher'})
# Created or merged node: (_138:medium {name: 'literature'})
# Created relationship: (literature)-[:isDistributedto {}]->(teacher)
# Created or merged node: (_306:group {name: 'perspective countries'})
# Created or merged node: (_307:medium {name: 'benchmarking'})
# Created relationship: (benchmarking)-[:isDistributedto {}]->(perspective countries)
# Created or merged node: (_280:group {name: 'student'})
# Created or merged node: (_28:medium {name: 'book'})
# Created relationship: (book)-[:isDistributedto {}]->(student)
# Created or merged node: (_308:group {name: 'electricians'})
# Created or merged node: (_309:media {name: 'maps'})
# Created or merged node: (_310:media {name: 'blueprints'})
# Created relationship: (electricians)-[:isInformedby {}]->(maps)
# Created relationship: (electricians)-[:isInformedby {}]->(blueprints)
# Created or merged node: (_311:medium {name: 'spam'})
# Created or merged node: (_312:group {name: 'clients'})
# Created relationship: (spam)-[:isDistributedto {}]->(clients)
# Created or merged node: (_313:group {name: 'prosecution'})
# Created or merged node: (_314:medium {name: 'gibbs trial'})
# Created relationship: (gibbs trial)-[:isDistributedto {}]->(prosecution)
# Created or merged node: (_315:group {name: 'construction workers'})
# Created or merged node: (_316:medium {name: 'petition'})
# Created or merged node: (_317:group {name: 'governor'})
# Created relationship: (petition)-[:isDistributedto {}]->(construction workers)
# Created relationship: (petition)-[:isDistributedto {}]->(governor)
# Created or merged node: (_273:group {name: 'staff'})
# Created or merged node: (_124:group {name: 'people'})
# Created or merged node: (_318:medium {name: 'product survey'})
# Created relationship: (product survey)-[:isDistributedto {}]->(staff)
# Created relationship: (product survey)-[:isDistributedto {}]->(people)
# Created or merged node: (_319:medium {name: 'viewing window'})
# Created or merged node: (_320:group {name: 'young girl'})
# Created relationship: (viewing window)-[:isDistributedto {}]->(young girl)
# Created or merged node: (_321:content {name: 'interview'})
# Created or merged node: (_322:group {name: 'presidential candidate'})
# Created or merged node: (_323:medium {name: 'show'})
# Created relationship: (interview)-[:isRecivedby {}]->(presidential candidate)
# Created relationship: (show)-[:isDistributedto {}]->(presidential candidate)
# Created or merged node: (_324:group {name: 'child'})
# Created or merged node: (_325:medium {name: 'outlet'})
# Created relationship: (outlet)-[:isDistributedto {}]->(child)
# Created or merged node: (_326:group {name: 'users'})
# Created or merged node: (_327:content {name: 'array'})
# Created or merged node: (_328:group {name: 'responder'})
# Created relationship: (array)-[:isRecivedby {}]->(users)
# Created relationship: (array)-[:isRecivedby {}]->(responder)
# Created or merged node: (_329:group {name: 'exhibitors'})
# Created or merged node: (_330:group {name: 'exhibits'})
# Created or merged node: (_331:media {name: 'fall fair'})
# Created relationship: (exhibitors)-[:isInformedby {}]->(fall fair)
# Created relationship: (exhibits)-[:isInformedby {}]->(fall fair)
# Created or merged node: (_332:group {name: 'editors'})
# Created or merged node: (_333:content {name: 'narration'})
# Created or merged node: (_334:content {name: 'description'})
# Created relationship: (narration)-[:isRecivedby {}]->(editors)
# Created relationship: (description)-[:isRecivedby {}]->(editors)
# Created or merged node: (_335:group {name: 'athlete'})
# Created or merged node: (_336:content {name: 'hurdle'})
# Created relationship: (hurdle)-[:isRecivedby {}]->(athlete)
# Created or merged node: (_337:group {name: 'celebrity'})
# Created or merged node: (_338:media {name: 'modern artwork'})
# Created relationship: (celebrity)-[:isInformedby {}]->(modern artwork)
# Created or merged node: (_220:group {name: 'poet'})
# Created or merged node: (_222:content {name: 'poems'})
# Created or merged node: (_339:medium {name: 'contests'})
# Created relationship: (poems)-[:isRecivedby {}]->(poet)
# Created relationship: (contests)-[:isDistributedto {}]->(poet)
# Created or merged node: (_340:group {name: 'voters'})
# Created or merged node: (_341:media {name: 'cameras'})
# Created relationship: (voters)-[:isInformedby {}]->(cameras)
# Created or merged node: (_342:group {name: 'schoener'})
# Created or merged node: (_343:content {name: 'maps'})
# Created or merged node: (_344:content {name: 'portfolio'})
# Created or merged node: (_345:group {name: 'german prince'})
# Created relationship: (maps)-[:isRecivedby {}]->(schoener)
# Created relationship: (maps)-[:isRecivedby {}]->(german prince)
# Created relationship: (portfolio)-[:isRecivedby {}]->(schoener)
# Created relationship: (portfolio)-[:isRecivedby {}]->(german prince)
# Created or merged node: (_346:medium {name: 'magazines'})
# Created or merged node: (_347:group {name: 'subscribers'})
# Created relationship: (magazines)-[:isDistributedto {}]->(subscribers)
# Created or merged node: (_348:group {name: 'insurgents'})
# Created or merged node: (_349:content {name: 'grenade'})
# Created or merged node: (_350:group {name: 'crowd'})
# Created relationship: (grenade)-[:isRecivedby {}]->(insurgents)
# Created relationship: (grenade)-[:isRecivedby {}]->(crowd)
# Created or merged node: (_351:group {name: 'actress'})
# Created or merged node: (_352:content {name: 'nude photos'})
# Created or merged node: (_353:media {name: 'local journal'})
# Created relationship: (actress)-[:isInformedby {}]->(local journal)
# Created relationship: (nude photos)-[:isRecivedby {}]->(actress)
# Created or merged node: (_354:medium {name: 'sino-u.s. joint statement'})
# Created or merged node: (_355:group {name: 'ties'})
# Created relationship: (sino-u.s. joint statement)-[:isDistributedto {}]->(ties)
# Created or merged node: (_356:media {name: 'mammography films'})
# Created or merged node: (_288:group {name: 'viewers'})
# Created relationship: (viewers)-[:isInformedby {}]->(mammography films)
# Created or merged node: (_357:group {name: 'iraqi air force pilots'})
# Created or merged node: (_358:medium {name: 'history'})
# Created relationship: (history)-[:isDistributedto {}]->(iraqi air force pilots)
# Created or merged node: (_359:media {name: 'soap'})
# Created or merged node: (_360:medium {name: 'prime time'})
# Created relationship: (prime time)-[:isDisplayedvia {}]->(soap)
# Created or merged node: (_361:group {name: 'operator'})
# Created or merged node: (_272:content {name: 'data'})
# Created relationship: (data)-[:isRecivedby {}]->(operator)
# Created or merged node: (_362:group {name: 'kids'})
# Created or merged node: (_363:content {name: 'bubbles'})
# Created relationship: (bubbles)-[:isRecivedby {}]->(kids)
# Created or merged node: (_364:medium {name: 'pictures'})
# Created or merged node: (_365:group {name: 'twins'})
# Created or merged node: (_366:group {name: 'vikings'})
# Created relationship: (pictures)-[:isDistributedto {}]->(twins)
# Created relationship: (pictures)-[:isDistributedto {}]->(vikings)
# Created or merged node: (_367:medium {name: 'steam-engine'})
# Created or merged node: (_368:group {name: 'prey'})
# Created relationship: (steam-engine)-[:isDistributedto {}]->(prey)
# Created or merged node: (_369:medium {name: 'scripts'})
# Created or merged node: (_370:group {name: 'visually impaired individuals'})
# Created or merged node: (_371:medium {name: 'programming'})
# Created relationship: (scripts)-[:isDistributedto {}]->(visually impaired individuals)
# Created relationship: (programming)-[:isDistributedto {}]->(visually impaired individuals)
# Created or merged node: (_92:medium {name: 'music'})
# Created or merged node: (_372:group {name: 'unemployment'})
# Created relationship: (music)-[:isDistributedto {}]->(unemployment)
# Created or merged node: (_373:group {name: 'guitarist'})
# Created or merged node: (_92:medium {name: 'music'})
# Created relationship: (music)-[:isDistributedto {}]->(guitarist)
# Created or merged node: (_374:medium {name: 'web-based system'})
# Created or merged node: (_375:content {name: 'confidential information leakage'})
# Created or merged node: (_232:group {name: 'person'})
# Created relationship: (web-based system)-[:isDistributedto {}]->(person)
# Created relationship: (confidential information leakage)-[:isRecivedby {}]->(person)
# Created or merged node: (_376:media {name: 'video'})
# Created or merged node: (_377:medium {name: 'tsunami waves'})
# Created relationship: (tsunami waves)-[:isDisplayedvia {}]->(video)
# Created or merged node: (_378:medium {name: 'cable television'})
# Created or merged node: (_379:medium {name: 'analog terrestrial television'})
# Created or merged node: (_380:medium {name: 'satellite television'})
# Created or merged node: (_376:media {name: 'video'})
# Created or merged node: (_381:content {name: 'film content'})
# Created or merged node: (_382:medium {name: 'internet'})
# Created relationship: (cable television)-[:isDisplayedvia {}]->(video)
# Created relationship: (analog terrestrial television)-[:isDisplayedvia {}]->(video)
# Created relationship: (satellite television)-[:isDisplayedvia {}]->(video)
# Created relationship: (internet)-[:isDisplayedvia {}]->(video)
# Created or merged node: (_295:group {name: 'children'})
# Created or merged node: (_383:medium {name: 'earthquake'})
# Created relationship: (earthquake)-[:isDistributedto {}]->(children)
# Created or merged node: (_384:medium {name: 'song'})
# Created or merged node: (_385:group {name: 'species of whales'})
# Created or merged node: (_386:group {name: 'humpback whale'})
# Created relationship: (song)-[:isDistributedto {}]->(species of whales)
# Created relationship: (song)-[:isDistributedto {}]->(humpback whale)
# Created or merged node: (_387:medium {name: 'paper'})
# Created or merged node: (_11:group {name: 'audience'})
# Created relationship: (paper)-[:isDistributedto {}]->(audience)
# Created or merged node: (_388:group {name: 'tv reporters'})
# Created or merged node: (_389:content {name: 'man-made disaster'})
# Created relationship: (man-made disaster)-[:isRecivedby {}]->(tv reporters)
# Created or merged node: (_390:medium {name: 'protocol'})
# Created or merged node: (_391:group {name: 'patients'})
# Created relationship: (protocol)-[:isDistributedto {}]->(patients)
# Created or merged node: (_392:medium {name: 'backpage'})
# Created or merged node: (_393:media {name: 'news paper'})
# Created relationship: (backpage)-[:isDisplayedvia {}]->(news paper)
# Created or merged node: (_394:group {name: 'ferrets'})
# Created or merged node: (_395:medium {name: 'smoke'})
# Created relationship: (smoke)-[:isDistributedto {}]->(ferrets)
# Created or merged node: (_396:media {name: 'radio'})
# Created or merged node: (_397:group {name: 'engine driver'})
# Created relationship: (engine driver)-[:isInformedby {}]->(radio)
# Created or merged node: (_398:group {name: 'suicides'})
# Created or merged node: (_399:media {name: 'frontpage'})
# Created or merged node: (_393:media {name: 'news paper'})
# Created or merged node: (_400:group {name: 'national suicide rates'})
# Created relationship: (suicides)-[:isInformedby {}]->(frontpage)
# Created relationship: (suicides)-[:isInformedby {}]->(news paper)
# Created relationship: (national suicide rates)-[:isInformedby {}]->(frontpage)
# Created relationship: (national suicide rates)-[:isInformedby {}]->(news paper)
# Created or merged node: (_401:media {name: 'sonar'})
# Created or merged node: (_402:group {name: 'fish'})
# Created relationship: (fish)-[:isInformedby {}]->(sonar)
# Created or merged node: (_403:medium {name: 'artwork'})
# Created or merged node: (_404:content {name: 'artifacts'})
# ...
# Created relationship: (album)-[:isDistributedto {}]->(three musicians)
# Created relationship: (material)-[:isRecivedby {}]->(three musicians)
# Created or merged node: (_432:group {name: 'friend'})
# Created or merged node: (_820:medium {name: 'map'})
# Created relationship: (map)-[:isDistributedto {}]->(friend)
# Created or merged node: (_2535:group {name: 'dolphins'})
# Created or merged node: (_2536:medium {name: 'tools'})
# Created or merged node: (_2537:medium {name: 'entertainment'})
# Created relationship: (tools)-[:isDistributedto {}]->(dolphins)
# Created relationship: (entertainment)-[:isDistributedto {}]->(dolphins)
# Created or merged node: (_948:group {name: 'editor'})
# Created or merged node: (_2538:medium {name: 'reviewing toolbar'})
# Created relationship: (reviewing toolbar)-[:isDistributedto {}]->(editor)
# Created or merged node: (_30:medium {name: 'film'})
# Created or merged node: (_959:group {name: 'critics'})
# Created relationship: (film)-[:isDistributedto {}]->(critics)
# Created or merged node: (_2539:group {name: 'radical cleric'})
# Created or merged node: (_2540:medium {name: 'english-language web site'})
# Created relationship: (english-language web site)-[:isDistributedto {}]->(radical cleric)
# Created or merged node: (_2541:medium {name: 'ballot'})
# Created or merged node: (_2542:group {name: 'national leaders'})
# Created relationship: (ballot)-[:isDistributedto {}]->(national leaders)
# Created or merged node: (_2543:medium {name: 'rss'})
# Created or merged node: (_2544:group {name: 'social classes'})
# Created or merged node: (_2545:group {name: 'working class'})
# Created relationship: (rss)-[:isDistributedto {}]->(social classes)
# Created relationship: (rss)-[:isDistributedto {}]->(working class)
# Created or merged node: (_2546:medium {name: 'intelligence'})
# Created or merged node: (_2547:group {name: 'red baron flying ace'})
# Created or merged node: (_2548:group {name: 'vampire fighters'})
# Created relationship: (intelligence)-[:isDistributedto {}]->(red baron flying ace)
# Created relationship: (intelligence)-[:isDistributedto {}]->(vampire fighters)
# Created or merged node: (_2549:group {name: 'syndicate of chicago capitalists'})
# Created or merged node: (_48:content {name: 'information'})
# Created relationship: (information)-[:isRecivedby {}]->(syndicate of chicago capitalists)
# Created or merged node: (_1933:group {name: 'brigade'})
# Created or merged node: (_2550:group {name: 'master chefs'})
# Created or merged node: (_2551:content {name: 'menu'})
# Created relationship: (menu)-[:isRecivedby {}]->(brigade)
# Created relationship: (menu)-[:isRecivedby {}]->(master chefs)
# Created or merged node: (_1239:content {name: 'essays'})
# Created or merged node: (_730:group {name: 'scholars'})
# Created or merged node: (_2552:content {name: 'philosophical work'})
# Created relationship: (essays)-[:isRecivedby {}]->(scholars)
# Created relationship: (philosophical work)-[:isRecivedby {}]->(scholars)
# Created or merged node: (_2553:medium {name: 'scope'})
# Created or merged node: (_2554:group {name: 'butterflies'})
# Created relationship: (scope)-[:isDistributedto {}]->(butterflies)
# Created or merged node: (_1076:content {name: 'questions'})
# Created or merged node: (_623:group {name: 'government'})
# Created or merged node: (_71:group {name: 'religion'})
# Created relationship: (questions)-[:isRecivedby {}]->(government)
# Created relationship: (questions)-[:isRecivedby {}]->(religion)
# Created or merged node: (_1499:media {name: 'film'})
# Created or merged node: (_2555:group {name: 'b-17 flight personnel'})
# Created or merged node: (_2556:group {name: 'squadron'})
# Created or merged node: (_2557:group {name: 'bombers'})
# Created relationship: (b-17 flight personnel)-[:isInformedby {}]->(film)
# Created relationship: (squadron)-[:isInformedby {}]->(film)
# Created relationship: (bombers)-[:isInformedby {}]->(film)
# Created or merged node: (_1451:media {name: 'series'})
# Created or merged node: (_2558:group {name: 'princess'})
# Created or merged node: (_2559:group {name: 'amazon women'})
# Created or merged node: (_2560:group {name: 'nazis'})
# Created relationship: (princess)-[:isInformedby {}]->(series)
# Created relationship: (amazon women)-[:isInformedby {}]->(series)
# Created relationship: (nazis)-[:isInformedby {}]->(series)
# Created or merged node: (_2561:medium {name: 'lawsuits'})
# Created or merged node: (_966:group {name: 'fans'})
# Created relationship: (lawsuits)-[:isDistributedto {}]->(fans)
# Created or merged node: (_1976:medium {name: 'train'})
# Created or merged node: (_1155:group {name: 'viewer'})
# Created or merged node: (_1881:medium {name: 'screen'})
# Created relationship: (train)-[:isDistributedto {}]->(viewer)
# Created relationship: (screen)-[:isDistributedto {}]->(viewer)
# Created or merged node: (_56:content {name: 'story'})
# Created or merged node: (_174:group {name: 'family'})
# Created or merged node: (_2562:content {name: 'epic story'})
# Created or merged node: (_2563:content {name: 'childlike innocence'})
# Created or merged node: (_2564:group {name: 'human race'})
# Created relationship: (story)-[:isRecivedby {}]->(family)
# Created relationship: (story)-[:isRecivedby {}]->(human race)
# Created relationship: (epic story)-[:isRecivedby {}]->(family)
# Created relationship: (epic story)-[:isRecivedby {}]->(human race)
# Created relationship: (childlike innocence)-[:isRecivedby {}]->(family)
# Created relationship: (childlike innocence)-[:isRecivedby {}]->(human race)
# Created or merged node: (_1060:content {name: 'statement'})
# Created or merged node: (_184:group {name: 'writer'})
# Created or merged node: (_1614:content {name: 'ideas'})
# Created relationship: (statement)-[:isRecivedby {}]->(writer)
# Created relationship: (ideas)-[:isRecivedby {}]->(writer)
# Created or merged node: (_2565:medium {name: 'academical source'})
# Created or merged node: (_2566:group {name: 'epicurean'})
# Created or merged node: (_2567:group {name: 'anti-epicurean'})
# Created relationship: (academical source)-[:isDistributedto {}]->(epicurean)
# Created relationship: (academical source)-[:isDistributedto {}]->(anti-epicurean)
# Created or merged node: (_2568:group {name: 'cars'})
# Created or merged node: (_2569:medium {name: 'upstream signal'})
# Created relationship: (upstream signal)-[:isDistributedto {}]->(cars)
# Created or merged node: (_280:group {name: 'student'})
# Created or merged node: (_245:medium {name: 'interview'})
# Created relationship: (interview)-[:isDistributedto {}]->(student)
# Created or merged node: (_1356:medium {name: 'e-mail'})
# Created or merged node: (_2570:group {name: 'member'})
# Created or merged node: (_295:group {name: 'children'})
# Created or merged node: (_2571:media {name: 'gocam'})
# Created relationship: (e-mail)-[:isDistributedto {}]->(member)
# Created relationship: (e-mail)-[:isDistributedto {}]->(children)
# Created relationship: (e-mail)-[:isDisplayedvia {}]->(gocam)
# Created relationship: (member)-[:isInformedby {}]->(gocam)
# Created relationship: (children)-[:isInformedby {}]->(gocam)
# Created or merged node: (_2572:group {name: 'diaspora'})
# Created or merged node: (_2573:content {name: 'language'})
# Created or merged node: (_138:medium {name: 'literature'})
# Created relationship: (language)-[:isRecivedby {}]->(diaspora)
# Created relationship: (literature)-[:isDistributedto {}]->(diaspora)
# Created or merged node: (_2574:medium {name: 'cross over'})
# Created or merged node: (_1290:group {name: 'drivers'})
# Created relationship: (cross over)-[:isDistributedto {}]->(drivers)
# Created or merged node: (_2575:group {name: 'forum goons'})
# Created or merged node: (_2576:content {name: 'products'})
# Created relationship: (products)-[:isRecivedby {}]->(forum goons)
# Created or merged node: (_428:group {name: 'singer'})
# Created or merged node: (_203:content {name: 'songs'})
# Created relationship: (songs)-[:isRecivedby {}]->(singer)
# Created or merged node: (_2577:group {name: 'patrons'})
# Created or merged node: (_771:content {name: 'books'})
# Created or merged node: (_326:group {name: 'users'})
# Created or merged node: (_771:content {name: 'books'})
# Created or merged node: (_898:medium {name: 'online'})
# Created relationship: (books)-[:isRecivedby {}]->(patrons)
# Created relationship: (books)-[:isRecivedby {}]->(users)
# Created relationship: (books)-[:isRecivedby {}]->(patrons)
# Created relationship: (books)-[:isRecivedby {}]->(users)
# Created relationship: (online)-[:isDistributedto {}]->(patrons)
# Created relationship: (online)-[:isDistributedto {}]->(users)
# Created or merged node: (_2578:media {name: 'web'})
# Created or merged node: (_124:group {name: 'people'})
# Created or merged node: (_2579:content {name: 'political commentary'})
# Created relationship: (people)-[:isInformedby {}]->(web)
# Created relationship: (political commentary)-[:isRecivedby {}]->(people)
# Created or merged node: (_2580:group {name: 'communal divide'})
# Created or merged node: (_1088:content {name: 'truth'})
# Created relationship: (truth)-[:isRecivedby {}]->(communal divide)
# Created or merged node: (_2581:medium {name: 'weather'})
# Created or merged node: (_2076:group {name: 'deaths'})
# Created relationship: (weather)-[:isDistributedto {}]->(deaths)
# Created or merged node: (_86:group {name: 'birds'})
# Created or merged node: (_505:medium {name: 'air'})
# Created relationship: (air)-[:isDistributedto {}]->(birds)
# Created or merged node: (_2582:media {name: 'videotape'})
# Created or merged node: (_881:group {name: 'men'})
# Created relationship: (men)-[:isInformedby {}]->(videotape)
# Created or merged node: (_2583:media {name: 'galleries'})
# Created or merged node: (_709:content {name: 'pics'})
# Created or merged node: (_2584:group {name: 'guys'})
# Created relationship: (pics)-[:isRecivedby {}]->(guys)
# Created relationship: (guys)-[:isInformedby {}]->(galleries)
# Created or merged node: (_88:group {name: 'witness'})
# Created or merged node: (_88:group {name: 'witness'})
# Created or merged node: (_2585:content {name: 'factual account'})
# Created relationship: (factual account)-[:isRecivedby {}]->(witness)
# Created relationship: (factual account)-[:isRecivedby {}]->(witness)
# Created or merged node: (_2586:group {name: 'catfish'})
# Created or merged node: (_2587:medium {name: 'heptachlor'})
# Created relationship: (heptachlor)-[:isDistributedto {}]->(catfish)
# Created or merged node: (_2588:group {name: 'prophet'})
# Created or merged node: (_2589:medium {name: 'biographies'})
# Created relationship: (biographies)-[:isDistributedto {}]->(prophet)
# Created or merged node: (_2590:media {name: 'record'})
# Created or merged node: (_2:medium {name: 'article'})
# Created relationship: (article)-[:isDisplayedvia {}]->(record)
# Created or merged node: (_2591:group {name: 'bisexuality'})
# Created or merged node: (_28:medium {name: 'book'})
# Created relationship: (book)-[:isDistributedto {}]->(bisexuality)
# Created or merged node: (_28:medium {name: 'book'})
# Created or merged node: (_2592:content {name: 'full-page color photos'})
# Created or merged node: (_2593:content {name: 'word list'})
# Created or merged node: (_2594:group {name: 'young readers'})
# Created relationship: (book)-[:isDistributedto {}]->(young readers)
# Created relationship: (full-page color photos)-[:isRecivedby {}]->(young readers)
# Created relationship: (word list)-[:isRecivedby {}]->(young readers)
# Created or merged node: (_82:group {name: 'politics'})
# Created or merged node: (_2595:content {name: 'parodies'})
# Created or merged node: (_2596:medium {name: 'live'})
# Created relationship: (parodies)-[:isRecivedby {}]->(politics)
# Created relationship: (live)-[:isDistributedto {}]->(politics)
# Created or merged node: (_2597:group {name: 'ospreys'})
# Created or merged node: (_138:medium {name: 'literature'})
# Created relationship: (literature)-[:isDistributedto {}]->(ospreys)
# Created or merged node: (_2598:content {name: 'amendment'})
# Created or merged node: (_2599:content {name: 'semicolon'})
# Created or merged node: (_2600:content {name: 'religious exemption portion'})
# Created or merged node: (_2601:content {name: 'comma'})
# Created or merged node: (_2602:group {name: 'senate scribe'})
# Created relationship: (amendment)-[:isRecivedby {}]->(senate scribe)
# Created relationship: (semicolon)-[:isRecivedby {}]->(senate scribe)
# Created relationship: (religious exemption portion)-[:isRecivedby {}]->(senate scribe)
# Created relationship: (comma)-[:isRecivedby {}]->(senate scribe)
# Created or merged node: (_3:group {name: 'authors'})
# Created or merged node: (_2603:group {name: 'groundswell'})
# Created or merged node: (_804:media {name: 'blogs'})
# Created or merged node: (_2604:media {name: 'wikis'})
# Created or merged node: (_2603:group {name: 'groundswell'})
# Created relationship: (authors)-[:isInformedby {}]->(blogs)
# Created relationship: (authors)-[:isInformedby {}]->(wikis)
# Created relationship: (groundswell)-[:isInformedby {}]->(blogs)
# Created relationship: (groundswell)-[:isInformedby {}]->(wikis)
# Created relationship: (groundswell)-[:isInformedby {}]->(blogs)
# Created relationship: (groundswell)-[:isInformedby {}]->(wikis)
# Created or merged node: (_272:content {name: 'data'})
# Created or merged node: (_2605:group {name: 'technician'})
# Created relationship: (data)-[:isRecivedby {}]->(technician)
# Created or merged node: (_41:medium {name: 'document'})
# Created or merged node: (_2606:group {name: 'indian missions'})
# Created relationship: (document)-[:isDistributedto {}]->(indian missions)
# Created or merged node: (_407:content {name: 'text'})
# Created or merged node: (_2607:group {name: 'iranian potter'})
# Created or merged node: (_2608:content {name: 'recepies'})
# Created relationship: (text)-[:isRecivedby {}]->(iranian potter)
# Created relationship: (recepies)-[:isRecivedby {}]->(iranian potter)
# Created or merged node: (_125:media {name: 'book'})
# Created or merged node: (_2609:group {name: 'danish academic'})
# Created relationship: (danish academic)-[:isInformedby {}]->(book)
# Created or merged node: (_2610:media {name: 'fiction'})
# Created or merged node: (_2611:content {name: 'software program'})
# Created or merged node: (_2612:group {name: 'bio-scientist'})
# Created relationship: (software program)-[:isRecivedby {}]->(bio-scientist)
# Created relationship: (bio-scientist)-[:isInformedby {}]->(fiction)
# Created or merged node: (_147:content {name: 'song'})
# Created or merged node: (_147:content {name: 'song'})
# Created or merged node: (_956:group {name: 'writers'})
# Created relationship: (song)-[:isRecivedby {}]->(writers)
# Created relationship: (song)-[:isRecivedby {}]->(writers)
# Created or merged node: (_2613:medium {name: 'universe'})
# Created or merged node: (_242:group {name: 'designer'})
# Created relationship: (universe)-[:isDistributedto {}]->(designer)
# Created or merged node: (_771:content {name: 'books'})
# Created or merged node: (_593:content {name: 'titles'})
# Created or merged node: (_2614:group {name: 'big-name authors'})
# Created relationship: (books)-[:isRecivedby {}]->(big-name authors)
# Created relationship: (titles)-[:isRecivedby {}]->(big-name authors)
# Created or merged node: (_382:medium {name: 'internet'})
# Created or merged node: (_752:group {name: 'individuals'})
# Created relationship: (internet)-[:isDistributedto {}]->(individuals)
# Created or merged node: (_706:content {name: 'article'})
# Created or merged node: (_246:group {name: 'author'})
# Created relationship: (article)-[:isRecivedby {}]->(author)
# Created or merged node: (_2615:group {name: 'quartet'})
# Created or merged node: (_2616:content {name: 'wedding song'})
# Created relationship: (wedding song)-[:isRecivedby {}]->(quartet)
# Created or merged node: (_2617:group {name: 'religious establishment'})
# Created or merged node: (_2618:content {name: 'tripe'})
# Created or merged node: (_2619:group {name: 'alchemists'})
# Created relationship: (tripe)-[:isRecivedby {}]->(religious establishment)
# Created relationship: (tripe)-[:isRecivedby {}]->(alchemists)
# Created or merged node: (_2620:media {name: 'dvd'})
# Created or merged node: (_764:group {name: 'mother'})
# Created relationship: (mother)-[:isInformedby {}]->(dvd)
# Nodes and relationships created successfully.

# %% [markdown]
# ### 4. General Descriptive Stats of the graph

# %%
query = """
MATCH (n)
OPTIONAL MATCH (n)-[r1]->()
OPTIONAL MATCH ()-[r2]->(n)
RETURN n, COUNT(r1) AS OutDegree, COUNT(r2) AS InDegree
"""

# Run the query
result = graph.run(query).data()

# Calculate cumulative degrees and sort the nodes
nodes_with_degrees = [
    {
        "node": record["n"],
        "cumulative_degree": record["OutDegree"] + record["InDegree"]
    }
    for record in result
]

# Sort nodes by cumulative degree in descending order
sorted_nodes = sorted(nodes_with_degrees, key=lambda x: x["cumulative_degree"], reverse=True)

# Print the sorted nodes with their cumulative degrees
for item in sorted_nodes:
    node = item["node"]
    cumulative_degree = item["cumulative_degree"]
    print(f"Node: {node}, Cumulative Degree: {cumulative_degree}")

print("Nodes sorted by cumulative degrees successfully.")
# Out:
# Node: (_124:group {name: 'people'}), Cumulative Degree: 880
# Node: (_535:group {name: 'friends'}), Cumulative Degree: 150
# Node: (_246:group {name: 'author'}), Cumulative Degree: 72
# Node: (_28:medium {name: 'book'}), Cumulative Degree: 60
# Node: (_3:group {name: 'authors'}), Cumulative Degree: 54
# Node: (_121:group {name: 'women'}), Cumulative Degree: 52
# Node: (_303:group {name: 'user'}), Cumulative Degree: 52
# Node: (_683:group {name: 'team'}), Cumulative Degree: 52
# Node: (_184:group {name: 'writer'}), Cumulative Degree: 48
# Node: (_23:group {name: 'students'}), Cumulative Degree: 42
# Node: (_415:group {name: 'band'}), Cumulative Degree: 42
# Node: (_71:group {name: 'religion'}), Cumulative Degree: 36
# Node: (_280:group {name: 'student'}), Cumulative Degree: 36
# Node: (_174:group {name: 'family'}), Cumulative Degree: 32
# Node: (_295:group {name: 'children'}), Cumulative Degree: 32
# Node: (_70:group {name: 'science'}), Cumulative Degree: 30
# Node: (_216:group {name: 'researchers'}), Cumulative Degree: 30
# Node: (_326:group {name: 'users'}), Cumulative Degree: 30
# Node: (_412:group {name: 'readers'}), Cumulative Degree: 28
# Node: (_149:group {name: 'characters'}), Cumulative Degree: 26
# Node: (_82:group {name: 'politics'}), Cumulative Degree: 24
# Node: (_48:content {name: 'information'}), Cumulative Degree: 23
# Node: (_229:group {name: 'artist'}), Cumulative Degree: 23
# Node: (_11:group {name: 'audience'}), Cumulative Degree: 20
# Node: (_102:group {name: 'faculty'}), Cumulative Degree: 20
# Node: (_312:group {name: 'clients'}), Cumulative Degree: 20
# Node: (_288:group {name: 'viewers'}), Cumulative Degree: 18
# Node: (_1696:group {name: 'composer'}), Cumulative Degree: 18
# Node: (_2:medium {name: 'article'}), Cumulative Degree: 16
# Node: (_44:group {name: 'customers'}), Cumulative Degree: 16
# Node: (_569:group {name: 'reader'}), Cumulative Degree: 16
# Node: (_1472:group {name: 'participants'}), Cumulative Degree: 16
# Node: (_1499:media {name: 'film'}), Cumulative Degree: 15
# Node: (_1:group {name: 'players'}), Cumulative Degree: 14
# Node: (_92:medium {name: 'music'}), Cumulative Degree: 14
# Node: (_30:medium {name: 'film'}), Cumulative Degree: 13
# Node: (_771:content {name: 'books'}), Cumulative Degree: 13
# Node: (_273:group {name: 'staff'}), Cumulative Degree: 12
# Node: (_382:medium {name: 'internet'}), Cumulative Degree: 12
# Node: (_450:content {name: 'images'}), Cumulative Degree: 12
# Node: (_56:content {name: 'story'}), Cumulative Degree: 11
# Node: (_9:medium {name: 'volume'}), Cumulative Degree: 10
# Node: (_86:group {name: 'birds'}), Cumulative Degree: 10
# Node: (_138:medium {name: 'literature'}), Cumulative Degree: 10
# Node: (_220:group {name: 'poet'}), Cumulative Degree: 10
# Node: (_298:group {name: 'scientists'}), Cumulative Degree: 10
# Node: (_874:group {name: 'patient'}), Cumulative Degree: 10
# Node: (_970:medium {name: 'media'}), Cumulative Degree: 10
# Node: (_1060:content {name: 'statement'}), Cumulative Degree: 10
# Node: (_125:media {name: 'book'}), Cumulative Degree: 9
# Node: (_147:content {name: 'song'}), Cumulative Degree: 9
# Node: (_158:content {name: 'message'}), Cumulative Degree: 9
# Node: (_272:content {name: 'data'}), Cumulative Degree: 9
# Node: (_305:group {name: 'teacher'}), Cumulative Degree: 9
# Node: (_560:medium {name: 'movie'}), Cumulative Degree: 9
# Node: (_76:medium {name: 'exhibition'}), Cumulative Degree: 8
# Node: (_109:content {name: 'letter'}), Cumulative Degree: 8
# Node: (_127:medium {name: 'play'}), Cumulative Degree: 8
# Node: (_144:group {name: 'society'}), Cumulative Degree: 8
# Node: (_161:group {name: 'boys'}), Cumulative Degree: 8
# Node: (_162:group {name: 'girls'}), Cumulative Degree: 8
# Node: (_244:group {name: 'researcher'}), Cumulative Degree: 8
# Node: (_387:medium {name: 'paper'}), Cumulative Degree: 8
# Node: (_432:group {name: 'friend'}), Cumulative Degree: 8
# Node: (_558:group {name: 'animals'}), Cumulative Degree: 8
# Node: (_686:medium {name: 'email'}), Cumulative Degree: 8
# Node: (_759:group {name: 'executive'}), Cumulative Degree: 8
# Node: (_764:group {name: 'mother'}), Cumulative Degree: 8
# Node: (_881:group {name: 'men'}), Cumulative Degree: 8
# Node: (_900:group {name: 'man'}), Cumulative Degree: 8
# Node: (_1153:medium {name: 'painting'}), Cumulative Degree: 8
# Node: (_1166:group {name: 'photographer'}), Cumulative Degree: 8
# Node: (_1176:group {name: 'puppet'}), Cumulative Degree: 8
# Node: (_1199:group {name: 'contractors'}), Cumulative Degree: 8
# Node: (_1356:medium {name: 'e-mail'}), Cumulative Degree: 8
# Node: (_1969:group {name: 'artists'}), Cumulative Degree: 8
# Node: (_2459:group {name: 'five'}), Cumulative Degree: 8
# Node: (_0:medium {name: 'game'}), Cumulative Degree: 7
# Node: (_69:medium {name: 'news'}), Cumulative Degree: 7
# Node: (_139:group {name: 'worker'}), Cumulative Degree: 7
# Node: (_197:group {name: 'painter'}), Cumulative Degree: 7
# Node: (_232:group {name: 'person'}), Cumulative Degree: 7
# Node: (_235:medium {name: 'blog'}), Cumulative Degree: 7
# Node: (_376:media {name: 'video'}), Cumulative Degree: 7
# Node: (_396:media {name: 'radio'}), Cumulative Degree: 7
# Node: (_407:content {name: 'text'}), Cumulative Degree: 7
# Node: (_726:group {name: 'recipient'}), Cumulative Degree: 7
# Node: (_955:content {name: 'memoirs'}), Cumulative Degree: 7
# Node: (_1772:medium {name: 'constitution'}), Cumulative Degree: 7
# Node: (_1830:medium {name: 'contemporary events'}), Cumulative Degree: 7
# Node: (_8:group {name: 'soldiers'}), Cumulative Degree: 6
# Node: (_68:media {name: 'blog'}), Cumulative Degree: 6
# Node: (_85:medium {name: 'books'}), Cumulative Degree: 6
# Node: (_163:media {name: 'show'}), Cumulative Degree: 6
# Node: (_175:content {name: 'picture'}), Cumulative Degree: 6
# Node: (_201:media {name: 'website'}), Cumulative Degree: 6
# Node: (_217:medium {name: 'report'}), Cumulative Degree: 6
# Node: (_242:group {name: 'designer'}), Cumulative Degree: 6
# Node: (_287:medium {name: 'art'}), Cumulative Degree: 6
# Node: (_300:group {name: 'public'}), Cumulative Degree: 6
# Node: (_313:group {name: 'prosecution'}), Cumulative Degree: 6
# Node: (_402:group {name: 'fish'}), Cumulative Degree: 6
# Node: (_465:content {name: 'words'}), Cumulative Degree: 6
# Node: (_547:medium {name: 'berserk'}), Cumulative Degree: 6
# Node: (_567:media {name: 'novel'}), Cumulative Degree: 6
# Node: (_658:group {name: 'conservative'}), Cumulative Degree: 6
# Node: (_680:medium {name: 'movies'}), Cumulative Degree: 6
# Node: (_706:content {name: 'article'}), Cumulative Degree: 6
# Node: (_752:group {name: 'individuals'}), Cumulative Degree: 6
# Node: (_852:group {name: 'mockingbirds'}), Cumulative Degree: 6
# Node: (_861:group {name: 'early african societies'}), Cumulative Degree: 6
# Node: (_988:media {name: 'magazines'}), Cumulative Degree: 6
# Node: (_1090:group {name: 'others'}), Cumulative Degree: 6
# Node: (_1130:medium {name: 'wire'}), Cumulative Degree: 6
# Node: (_1252:medium {name: 'storm'}), Cumulative Degree: 6
# Node: (_1329:group {name: 'inhabitants'}), Cumulative Degree: 6
# Node: (_1379:group {name: 'workers'}), Cumulative Degree: 6
# Node: (_1551:group {name: 'trust'}), Cumulative Degree: 6
# Node: (_1614:content {name: 'ideas'}), Cumulative Degree: 6
# Node: (_2067:medium {name: 'drug game'}), Cumulative Degree: 6
# Node: (_87:content {name: 'document'}), Cumulative Degree: 5
# Node: (_93:media {name: 'quarterly magazine'}), Cumulative Degree: 5
# Node: (_137:group {name: 'candidates'}), Cumulative Degree: 5
# Node: (_141:media {name: 'online journal'}), Cumulative Degree: 5
# Node: (_204:medium {name: 'album'}), Cumulative Degree: 5
# Node: (_234:medium {name: 'photograph'}), Cumulative Degree: 5
# Node: (_240:content {name: 'work'}), Cumulative Degree: 5
# Node: (_256:group {name: 'director'}), Cumulative Degree: 5
# Node: (_299:content {name: 'messages'}), Cumulative Degree: 5
# Node: (_391:group {name: 'patients'}), Cumulative Degree: 5
# Node: (_420:content {name: 'poem'}), Cumulative Degree: 5
# Node: (_445:content {name: 'recipe'}), Cumulative Degree: 5
# Node: (_472:group {name: 'scribe'}), Cumulative Degree: 5
# Node: (_483:medium {name: 'symposium'}), Cumulative Degree: 5
# Node: (_492:content {name: 'articles'}), Cumulative Degree: 5
# Node: (_511:media {name: 'second movie'}), Cumulative Degree: 5
# Node: (_534:group {name: 'musicians'}), Cumulative Degree: 5
# Node: (_583:content {name: 'material'}), Cumulative Degree: 5
# Node: (_665:group {name: 'painters'}), Cumulative Degree: 5
# Node: (_765:medium {name: 'picture'}), Cumulative Degree: 5
# Node: (_820:medium {name: 'map'}), Cumulative Degree: 5
# Node: (_839:media {name: 'books'}), Cumulative Degree: 5
# Node: (_887:medium {name: 'code'}), Cumulative Degree: 5
# Node: (_1070:group {name: 'devices'}), Cumulative Degree: 5
# Node: (_1093:medium {name: 'novel'}), Cumulative Degree: 5
# Node: (_1188:group {name: 'scientist'}), Cumulative Degree: 5
# Node: (_1200:content {name: 'documents'}), Cumulative Degree: 5
# Node: (_1286:medium {name: 'study'}), Cumulative Degree: 5
# Node: (_1335:group {name: 'police'}), Cumulative Degree: 5
# Node: (_1405:group {name: '5-year-old girl'}), Cumulative Degree: 5
# Node: (_1451:media {name: 'series'}), Cumulative Degree: 5
# Node: (_1463:medium {name: 'speech'}), Cumulative Degree: 5
# Node: (_1502:content {name: 'themes'}), Cumulative Degree: 5
# Node: (_1600:content {name: 'kidnapping'}), Cumulative Degree: 5
# Node: (_1662:group {name: 'directors'}), Cumulative Degree: 5
# Node: (_1808:medium {name: 'wood'}), Cumulative Degree: 5
# Node: (_1958:group {name: 'speaker'}), Cumulative Degree: 5
# Node: (_1964:group {name: 'stars'}), Cumulative Degree: 5
# Node: (_2102:group {name: 'professors'}), Cumulative Degree: 5
# Node: (_2469:group {name: 'lead'}), Cumulative Degree: 5
# Node: (_47:group {name: 'families'}), Cumulative Degree: 4
# Node: (_57:group {name: 'boy'}), Cumulative Degree: 4
# Node: (_83:group {name: 'class'}), Cumulative Degree: 4
# Node: (_88:group {name: 'witness'}), Cumulative Degree: 4
# Node: (_103:content {name: 'works'}), Cumulative Degree: 4
# Node: (_131:medium {name: 'stories'}), Cumulative Degree: 4
# Node: (_153:group {name: 'education'}), Cumulative Degree: 4
# Node: (_167:media {name: 'press'}), Cumulative Degree: 4
# Node: (_186:group {name: 'musician'}), Cumulative Degree: 4
# Node: (_203:content {name: 'songs'}), Cumulative Degree: 4
# Node: (_245:medium {name: 'interview'}), Cumulative Degree: 4
# Node: (_255:content {name: 'book'}), Cumulative Degree: 4
# Node: (_291:content {name: 'image'}), Cumulative Degree: 4
# Node: (_316:medium {name: 'petition'}), Cumulative Degree: 4
# Node: (_340:group {name: 'voters'}), Cumulative Degree: 4
# Node: (_350:group {name: 'crowd'}), Cumulative Degree: 4
# Node: (_394:group {name: 'ferrets'}), Cumulative Degree: 4
# Node: (_428:group {name: 'singer'}), Cumulative Degree: 4
# Node: (_449:group {name: 'software developer'}), Cumulative Degree: 4
# Node: (_453:group {name: 'saint'}), Cumulative Degree: 4
# Node: (_457:medium {name: 'feet of clay'}), Cumulative Degree: 4
# Node: (_500:group {name: 'archers'}), Cumulative Degree: 4
# Node: (_538:group {name: 'riffraff'}), Cumulative Degree: 4
# Node: (_541:content {name: 'lies'}), Cumulative Degree: 4
# Node: (_578:content {name: 'novel'}), Cumulative Degree: 4
# Node: (_673:group {name: 'heroes'}), Cumulative Degree: 4
# Node: (_681:medium {name: 'television'}), Cumulative Degree: 4
# Node: (_701:group {name: 'group'}), Cumulative Degree: 4
# Node: (_730:group {name: 'scholars'}), Cumulative Degree: 4
# Node: (_766:content {name: 'designs'}), Cumulative Degree: 4
# Node: (_767:group {name: 'professional'}), Cumulative Degree: 4
# Node: (_769:group {name: 'player'}), Cumulative Degree: 4
# Node: (_780:group {name: 'performer'}), Cumulative Degree: 4
# Node: (_781:group {name: 'programmers'}), Cumulative Degree: 4
# Node: (_787:group {name: 'humans'}), Cumulative Degree: 4
# Node: (_838:medium {name: 'ink'}), Cumulative Degree: 4
# Node: (_851:group {name: 'megan fox'}), Cumulative Degree: 4
# Node: (_898:medium {name: 'online'}), Cumulative Degree: 4
# Node: (_904:group {name: 'movement'}), Cumulative Degree: 4
# Node: (_934:group {name: 'consumers'}), Cumulative Degree: 4
# Node: (_946:group {name: 'people with disabilities'}), Cumulative Degree: 4
# Node: (_953:content {name: 'content'}), Cumulative Degree: 4
# Node: (_986:content {name: 'recipes'}), Cumulative Degree: 4
# Node: (_1004:group {name: 'cleaning lady'}), Cumulative Degree: 4
# Node: (_1053:group {name: 'performers'}), Cumulative Degree: 4
# Node: (_1098:medium {name: 'language'}), Cumulative Degree: 4
# Node: (_1133:group {name: 'listeners'}), Cumulative Degree: 4
# Node: (_1182:group {name: 'practitioners'}), Cumulative Degree: 4
# Node: (_1194:group {name: 'customer'}), Cumulative Degree: 4
# Node: (_1203:media {name: 'templates'}), Cumulative Degree: 4
# Node: (_1220:media {name: 'cd'}), Cumulative Degree: 4
# Node: (_1226:group {name: 'novelist'}), Cumulative Degree: 4
# Node: (_1236:content {name: 'notice of authorization'}), Cumulative Degree: 4
# Node: (_1240:group {name: 'leading experts'}), Cumulative Degree: 4
# Node: (_1270:group {name: 'little kid'}), Cumulative Degree: 4
# Node: (_1411:medium {name: 'box'}), Cumulative Degree: 4
# Node: (_1434:content {name: 'interviews'}), Cumulative Degree: 4
# Node: (_1453:group {name: 'celebrity students'}), Cumulative Degree: 4
# Node: (_1465:medium {name: 'portraits'}), Cumulative Degree: 4
# Node: (_1565:group {name: 'conferences'}), Cumulative Degree: 4
# Node: (_1617:medium {name: 'photos'}), Cumulative Degree: 4
# Node: (_1627:group {name: 'tribal communities'}), Cumulative Degree: 4
# Node: (_1649:group {name: 'steering committee'}), Cumulative Degree: 4
# Node: (_1653:group {name: 'girl'}), Cumulative Degree: 4
# Node: (_1657:group {name: 'songwriter'}), Cumulative Degree: 4
# Node: (_1680:content {name: 'papers'}), Cumulative Degree: 4
# Node: (_1709:medium {name: 'score'}), Cumulative Degree: 4
# Node: (_1762:content {name: 'coursework'}), Cumulative Degree: 4
# Node: (_1784:group {name: 'developer'}), Cumulative Degree: 4
# Node: (_1843:media {name: 'bush campaign'}), Cumulative Degree: 4
# Node: (_1852:group {name: 'pathologists'}), Cumulative Degree: 4
# Node: (_1928:medium {name: 'soccer game'}), Cumulative Degree: 4
# Node: (_2006:group {name: 'ward greene'}), Cumulative Degree: 4
# Node: (_2048:group {name: 'game show stars'}), Cumulative Degree: 4
# Node: (_2116:group {name: 'njcu athlete'}), Cumulative Degree: 4
# Node: (_2162:group {name: 'board'}), Cumulative Degree: 4
# Node: (_2170:group {name: 'investigator'}), Cumulative Degree: 4
# Node: (_2192:group {name: 'woman'}), Cumulative Degree: 4
# Node: (_2193:group {name: 'mormon faith'}), Cumulative Degree: 4
# Node: (_2213:medium {name: 'mud creation'}), Cumulative Degree: 4
# Node: (_2460:medium {name: 'website'}), Cumulative Degree: 4
# Node: (_2493:group {name: 'household'}), Cumulative Degree: 4
# Node: (_2494:medium {name: 'picture books'}), Cumulative Degree: 4
# Node: (_2501:group {name: 'mailing list'}), Cumulative Degree: 4
# Node: (_2602:group {name: 'senate scribe'}), Cumulative Degree: 4
# Node: (_4:medium {name: 'technology'}), Cumulative Degree: 3
# Node: (_12:media {name: 'television'}), Cumulative Degree: 3
# Node: (_18:medium {name: 'prose'}), Cumulative Degree: 3
# Node: (_20:group {name: 'great people'}), Cumulative Degree: 3
# Node: (_46:media {name: 'newsletter'}), Cumulative Degree: 3
# Node: (_49:group {name: 'employees'}), Cumulative Degree: 3
# Node: (_50:group {name: 'us'}), Cumulative Degree: 3
# Node: (_63:medium {name: 'bulletin'}), Cumulative Degree: 3
# Node: (_107:group {name: 'parent'}), Cumulative Degree: 3
# Node: (_154:medium {name: 'notification'}), Cumulative Degree: 3
# Node: (_166:medium {name: 'media criticism'}), Cumulative Degree: 3
# Node: (_179:content {name: 'list'}), Cumulative Degree: 3
# Node: (_210:content {name: 'topic'}), Cumulative Degree: 3
# Node: (_222:content {name: 'poems'}), Cumulative Degree: 3
# Node: (_223:group {name: 'creator'}), Cumulative Degree: 3
# Node: (_248:group {name: 'model maker'}), Cumulative Degree: 3
# Node: (_249:group {name: 'craftsperson'}), Cumulative Degree: 3
# Node: (_251:content {name: 'design'}), Cumulative Degree: 3
# Node: (_268:group {name: 'playwright'}), Cumulative Degree: 3
# Node: (_282:medium {name: 'telephone'}), Cumulative Degree: 3
# Node: (_286:group {name: 'merchant'}), Cumulative Degree: 3
# Node: (_302:group {name: 'parties'}), Cumulative Degree: 3
# Node: (_323:medium {name: 'show'}), Cumulative Degree: 3
# Node: (_349:content {name: 'grenade'}), Cumulative Degree: 3
# Node: (_364:medium {name: 'pictures'}), Cumulative Degree: 3
# Node: (_393:media {name: 'news paper'}), Cumulative Degree: 3
# Node: (_405:medium {name: 'exhibit'}), Cumulative Degree: 3
# Node: (_409:group {name: 'professional scribe'}), Cumulative Degree: 3
# Node: (_411:content {name: 'comments'}), Cumulative Degree: 3
# Node: (_425:group {name: 'allies'}), Cumulative Degree: 3
# Node: (_446:content {name: 'anecdote'}), Cumulative Degree: 3
# Node: (_503:medium {name: 'wars'}), Cumulative Degree: 3
# Node: (_505:medium {name: 'air'}), Cumulative Degree: 3
# Node: (_518:group {name: 'subjects'}), Cumulative Degree: 3
# Node: (_519:group {name: 'societies'}), Cumulative Degree: 3
# Node: (_537:media {name: 'email'}), Cumulative Degree: 3
# Node: (_540:content {name: 'argument'}), Cumulative Degree: 3
# Node: (_592:content {name: 'composition'}), Cumulative Degree: 3
# Node: (_598:medium {name: 'documentary'}), Cumulative Degree: 3
# Node: (_599:content {name: 'commentaries'}), Cumulative Degree: 3
# Node: (_600:group {name: 'thompson'}), Cumulative Degree: 3
# Node: (_601:group {name: 'peers'}), Cumulative Degree: 3
# Node: (_638:medium {name: 'rags'}), Cumulative Degree: 3
# Node: (_674:media {name: 'movies'}), Cumulative Degree: 3
# Node: (_676:content {name: 'records'}), Cumulative Degree: 3
# Node: (_678:group {name: 'walter'}), Cumulative Degree: 3
# Node: (_679:group {name: 'famous heroes'}), Cumulative Degree: 3
# Node: (_698:content {name: 'quotes'}), Cumulative Degree: 3
# Node: (_709:content {name: 'pics'}), Cumulative Degree: 3
# Node: (_721:group {name: '20 others'}), Cumulative Degree: 3
# Node: (_739:medium {name: 'tsunami'}), Cumulative Degree: 3
# Node: (_742:medium {name: 'trial'}), Cumulative Degree: 3
# Node: (_753:group {name: 'teams'}), Cumulative Degree: 3
# Node: (_755:content {name: 'news'}), Cumulative Degree: 3
# Node: (_760:group {name: 'legislature'}), Cumulative Degree: 3
# Node: (_776:group {name: 'teachers'}), Cumulative Degree: 3
# Node: (_804:media {name: 'blogs'}), Cumulative Degree: 3
# Node: (_831:media {name: 'videos'}), Cumulative Degree: 3
# Node: (_863:medium {name: 'games'}), Cumulative Degree: 3
# Node: (_873:content {name: 'questionnaire'}), Cumulative Degree: 3
# Node: (_960:group {name: 'actors'}), Cumulative Degree: 3
# Node: (_965:group {name: 'community'}), Cumulative Degree: 3
# Node: (_966:group {name: 'fans'}), Cumulative Degree: 3
# Node: (_994:content {name: 'question'}), Cumulative Degree: 3
# Node: (_1024:content {name: 'ct scans'}), Cumulative Degree: 3
# Node: (_1036:media {name: 'telegraph'}), Cumulative Degree: 3
# Node: (_1040:group {name: 'government agencies'}), Cumulative Degree: 3
# Node: (_1041:group {name: 'terrorists'}), Cumulative Degree: 3
# Node: (_1049:media {name: 'outdoors'}), Cumulative Degree: 3
# Node: (_1076:content {name: 'questions'}), Cumulative Degree: 3
# Node: (_1085:group {name: 'ancient pagan traditions'}), Cumulative Degree: 3
# Node: (_1088:content {name: 'truth'}), Cumulative Degree: 3
# Node: (_1099:group {name: 'race'}), Cumulative Degree: 3
# Node: (_1126:group {name: 'panel'}), Cumulative Degree: 3
# Node: (_1136:media {name: 'audio formats'}), Cumulative Degree: 3
# Node: (_1155:group {name: 'viewer'}), Cumulative Degree: 3
# Node: (_1161:group {name: 'hittite people'}), Cumulative Degree: 3
# Node: (_1167:content {name: 'pictures'}), Cumulative Degree: 3
# Node: (_1172:content {name: 'paragraph'}), Cumulative Degree: 3
# Node: (_1193:group {name: 'hacker'}), Cumulative Degree: 3
# Node: (_1217:medium {name: 'slide show'}), Cumulative Degree: 3
# Node: (_1218:media {name: 'blue slide'}), Cumulative Degree: 3
# Node: (_1221:medium {name: 'italian music'}), Cumulative Degree: 3
# Node: (_1239:content {name: 'essays'}), Cumulative Degree: 3
# Node: (_1244:media {name: 'state television'}), Cumulative Degree: 3
# Node: (_1278:medium {name: 'consensus paper'}), Cumulative Degree: 3
# Node: (_1297:media {name: 'audio'}), Cumulative Degree: 3
# Node: (_1302:content {name: 'memories'}), Cumulative Degree: 3
# Node: (_1348:content {name: 'flyers'}), Cumulative Degree: 3
# Node: (_1417:group {name: 'local dialect'}), Cumulative Degree: 3
# Node: (_1432:medium {name: 'music theatre'}), Cumulative Degree: 3
# Node: (_1433:medium {name: 'film music'}), Cumulative Degree: 3
# Node: (_1435:group {name: 'songwriters'}), Cumulative Degree: 3
# Node: (_1436:group {name: 'composers'}), Cumulative Degree: 3
# Node: (_1437:group {name: 'orchestrators'}), Cumulative Degree: 3
# Node: (_1467:medium {name: 'charts'}), Cumulative Degree: 3
# Node: (_1471:media {name: 'police report'}), Cumulative Degree: 3
# Node: (_1479:content {name: 'events'}), Cumulative Degree: 3
# Node: (_1503:group {name: 'everyone'}), Cumulative Degree: 3
# Node: (_1545:medium {name: 'ballads'}), Cumulative Degree: 3
# Node: (_1549:medium {name: 'foreign wars'}), Cumulative Degree: 3
# Node: (_1558:group {name: 'climate scientist'}), Cumulative Degree: 3
# Node: (_1560:group {name: 'science blogger'}), Cumulative Degree: 3
# Node: (_1586:media {name: 'photo story board'}), Cumulative Degree: 3
# Node: (_1589:medium {name: 'reports'}), Cumulative Degree: 3
# Node: (_1601:medium {name: 'photographs'}), Cumulative Degree: 3
# Node: (_1607:group {name: 'chickens'}), Cumulative Degree: 3
# Node: (_1619:group {name: 'refugees'}), Cumulative Degree: 3
# Node: (_1620:media {name: 'newspaper'}), Cumulative Degree: 3
# Node: (_1668:group {name: 'institutions'}), Cumulative Degree: 3
# Node: (_1687:group {name: 'failed families'}), Cumulative Degree: 3
# Node: (_1692:group {name: 'candidate'}), Cumulative Degree: 3
# Node: (_1706:group {name: 'cast'}), Cumulative Degree: 3
# Node: (_1732:medium {name: 'advertisement'}), Cumulative Degree: 3
# Node: (_1781:content {name: 'colours'}), Cumulative Degree: 3
# Node: (_1783:content {name: 'guidelines'}), Cumulative Degree: 3
# Node: (_1788:medium {name: 'keyboards'}), Cumulative Degree: 3
# Node: (_1800:group {name: 'population'}), Cumulative Degree: 3
# Node: (_1815:group {name: 'party'}), Cumulative Degree: 3
# Node: (_1819:medium {name: 'series'}), Cumulative Degree: 3
# Node: (_1839:content {name: 'slurs'}), Cumulative Degree: 3
# Node: (_1867:medium {name: 'ike'}), Cumulative Degree: 3
# Node: (_1879:group {name: 'school of fish'}), Cumulative Degree: 3
# Node: (_1884:medium {name: 'letters'}), Cumulative Degree: 3
# Node: (_1910:medium {name: 'ra 6938'}), Cumulative Degree: 3
# Node: (_1916:medium {name: 'huffman photograph'}), Cumulative Degree: 3
# Node: (_1922:medium {name: 'delta chi quarterly'}), Cumulative Degree: 3
# Node: (_1937:medium {name: 'sequel'}), Cumulative Degree: 3
# Node: (_1945:medium {name: 'space opera'}), Cumulative Degree: 3
# Node: (_1957:group {name: 'authority'}), Cumulative Degree: 3
# Node: (_1974:media {name: 'emails'}), Cumulative Degree: 3
# Node: (_1989:group {name: 'figure'}), Cumulative Degree: 3
# Node: (_2103:content {name: 'sociology of paraliterature'}), Cumulative Degree: 3
# Node: (_2104:content {name: 'hermeneutics of divination'}), Cumulative Degree: 3
# Node: (_2105:content {name: 'crime fiction'}), Cumulative Degree: 3
# Node: (_2108:group {name: 'anna'}), Cumulative Degree: 3
# Node: (_2123:group {name: 'freedman'}), Cumulative Degree: 3
# Node: (_2137:medium {name: 'paintings'}), Cumulative Degree: 3
# Node: (_2154:media {name: 'rostrum newspapers'}), Cumulative Degree: 3
# Node: (_2155:media {name: 'propaganda films'}), Cumulative Degree: 3
# Node: (_2181:content {name: 'meal'}), Cumulative Degree: 3
# Node: (_2188:content {name: 'food memoir'}), Cumulative Degree: 3
# Node: (_2190:medium {name: 'vampire novels'}), Cumulative Degree: 3
# Node: (_2194:media {name: 'horror books'}), Cumulative Degree: 3
# Node: (_2219:group {name: 'unknown author'}), Cumulative Degree: 3
# Node: (_2221:content {name: 'photograph'}), Cumulative Degree: 3
# Node: (_2227:medium {name: 'book-crossing'}), Cumulative Degree: 3
# Node: (_2237:group {name: 'red grooms'}), Cumulative Degree: 3
# Node: (_2239:group {name: 'chorus'}), Cumulative Degree: 3
# Node: (_2253:content {name: 'theme song'}), Cumulative Degree: 3
# Node: (_2273:group {name: "machine 's designers"}), Cumulative Degree: 3
# Node: (_2298:group {name: "bear 's stomach"}), Cumulative Degree: 3
# Node: (_2305:group {name: 'death walks among you'}), Cumulative Degree: 3
# Node: (_2307:medium {name: 'english'}), Cumulative Degree: 3
# Node: (_2340:medium {name: 'net'}), Cumulative Degree: 3
# Node: (_2398:content {name: 'economic statement'}), Cumulative Degree: 3
# Node: (_2429:group {name: 'trial'}), Cumulative Degree: 3
# Node: (_2438:medium {name: 'installation'}), Cumulative Degree: 3
# Node: (_2461:media {name: 'holy soap'}), Cumulative Degree: 3
# Node: (_2462:media {name: 'television soap operas'}), Cumulative Degree: 3
# Node: (_2463:medium {name: 'channels'}), Cumulative Degree: 3
# Node: (_2475:medium {name: 'drama'}), Cumulative Degree: 3
# Node: (_2530:group {name: 'record holder'}), Cumulative Degree: 3
# Node: (_2564:group {name: 'human race'}), Cumulative Degree: 3
# Node: (_2571:media {name: 'gocam'}), Cumulative Degree: 3
# Node: (_2594:group {name: 'young readers'}), Cumulative Degree: 3
# Node: (_5:group {name: 'small pharmacy chains'}), Cumulative Degree: 2
# Node: (_6:media {name: 'magazine'}), Cumulative Degree: 2
# Node: (_13:content {name: 'democracy of culture'}), Cumulative Degree: 2
# Node: (_14:group {name: 'english accent'}), Cumulative Degree: 2
# Node: (_15:medium {name: 'documents'}), Cumulative Degree: 2
# Node: (_33:group {name: 'parents'}), Cumulative Degree: 2
# Node: (_37:group {name: 'retirement'}), Cumulative Degree: 2
# Node: (_40:group {name: 'wheelchair basketball team'}), Cumulative Degree: 2
# Node: (_41:medium {name: 'document'}), Cumulative Degree: 2
# Node: (_72:media {name: 'weekly economic publication'}), Cumulative Degree: 2
# Node: (_73:group {name: 'financial'}), Cumulative Degree: 2
# Node: (_74:group {name: 'commercial'}), Cumulative Degree: 2
# Node: (_75:content {name: 'industrial developments'}), Cumulative Degree: 2
# Node: (_94:group {name: 'political'}), Cumulative Degree: 2
# Node: (_96:group {name: 'social'}), Cumulative Degree: 2
# Node: (_101:content {name: 'social history'}), Cumulative Degree: 2
# Node: (_106:group {name: 'history'}), Cumulative Degree: 2
# Node: (_113:content {name: 'guide'}), Cumulative Degree: 2
# Node: (_115:group {name: 'junior reporter'}), Cumulative Degree: 2
# Node: (_122:content {name: 'tricks'}), Cumulative Degree: 2
# Node: (_132:group {name: 'baseball player'}), Cumulative Degree: 2
# Node: (_142:group {name: 'sports'}), Cumulative Degree: 2
# Node: (_146:group {name: 'wolf'}), Cumulative Degree: 2
# Node: (_160:medium {name: 'lyrics'}), Cumulative Degree: 2
# Node: (_165:group {name: 'm & a experts'}), Cumulative Degree: 2
# Node: (_168:medium {name: 'weekly magazine'}), Cumulative Degree: 2
# Node: (_169:group {name: 'culture'}), Cumulative Degree: 2
# Node: (_170:content {name: 'style'}), Cumulative Degree: 2
# Node: (_173:group {name: 'daughter'}), Cumulative Degree: 2
# Node: (_176:group {name: 'ubc graduate student'}), Cumulative Degree: 2
# Node: (_177:content {name: 'colour'}), Cumulative Degree: 2
# Node: (_178:media {name: 'digital photos'}), Cumulative Degree: 2
# Node: (_183:content {name: 'family story'}), Cumulative Degree: 2
# Node: (_188:medium {name: 'anti-terrorism legislation'}), Cumulative Degree: 2
# Node: (_191:content {name: 'drawing'}), Cumulative Degree: 2
# Node: (_192:group {name: 'ghostwriters'}), Cumulative Degree: 2
# Node: (_195:medium {name: 'pencil'}), Cumulative Degree: 2
# Node: (_200:group {name: 'soldier'}), Cumulative Degree: 2
# Node: (_202:group {name: 'duo'}), Cumulative Degree: 2
# Node: (_205:group {name: 'producer'}), Cumulative Degree: 2
# Node: (_213:medium {name: 'september dossier'}), Cumulative Degree: 2
# Node: (_214:group {name: 'employee'}), Cumulative Degree: 2
# Node: (_225:group {name: 'physicist'}), Cumulative Degree: 2
# Node: (_237:group {name: 'designers'}), Cumulative Degree: 2
# Node: (_250:content {name: '3-dimensional representation'}), Cumulative Degree: 2
# Node: (_252:content {name: 'concept'}), Cumulative Degree: 2
# Node: (_254:content {name: 'introduction'}), Cumulative Degree: 2
# Node: (_258:group {name: 'school master'}), Cumulative Degree: 2
# Node: (_261:group {name: 'witch'}), Cumulative Degree: 2
# Node: (_267:group {name: 'pilot'}), Cumulative Degree: 2
# Node: (_274:content {name: 'aphorisms'}), Cumulative Degree: 2
# Node: (_275:group {name: 'biographer'}), Cumulative Degree: 2
# Node: (_276:group {name: 'personality'}), Cumulative Degree: 2
# Node: (_277:content {name: 'minutiae'}), Cumulative Degree: 2
# Node: (_292:medium {name: 'national discourse'}), Cumulative Degree: 2
# Node: (_297:medium {name: 'state of the art'}), Cumulative Degree: 2
# Node: (_301:medium {name: 'photo'}), Cumulative Degree: 2
# Node: (_308:group {name: 'electricians'}), Cumulative Degree: 2
# Node: (_318:medium {name: 'product survey'}), Cumulative Degree: 2
# Node: (_320:group {name: 'young girl'}), Cumulative Degree: 2
# Node: (_322:group {name: 'presidential candidate'}), Cumulative Degree: 2
# Node: (_324:group {name: 'child'}), Cumulative Degree: 2
# Node: (_327:content {name: 'array'}), Cumulative Degree: 2
# Node: (_329:group {name: 'exhibitors'}), Cumulative Degree: 2
# Node: (_331:media {name: 'fall fair'}), Cumulative Degree: 2
# Node: (_332:group {name: 'editors'}), Cumulative Degree: 2
# Node: (_334:content {name: 'description'}), Cumulative Degree: 2
# Node: (_342:group {name: 'schoener'}), Cumulative Degree: 2
# Node: (_343:content {name: 'maps'}), Cumulative Degree: 2
# Node: (_344:content {name: 'portfolio'}), Cumulative Degree: 2
# Node: (_345:group {name: 'german prince'}), Cumulative Degree: 2
# Node: (_351:group {name: 'actress'}), Cumulative Degree: 2
# Node: (_362:group {name: 'kids'}), Cumulative Degree: 2
# Node: (_369:medium {name: 'scripts'}), Cumulative Degree: 2
# Node: (_370:group {name: 'visually impaired individuals'}), Cumulative Degree: 2
# Node: (_384:medium {name: 'song'}), Cumulative Degree: 2
# Node: (_398:group {name: 'suicides'}), Cumulative Degree: 2
# Node: (_399:media {name: 'frontpage'}), Cumulative Degree: 2
# Node: (_400:group {name: 'national suicide rates'}), Cumulative Degree: 2
# Node: (_403:medium {name: 'artwork'}), Cumulative Degree: 2
# Node: (_404:content {name: 'artifacts'}), Cumulative Degree: 2
# Node: (_408:medium {name: 'transcript'}), Cumulative Degree: 2
# Node: (_410:group {name: 'sir dudley carleton'}), Cumulative Degree: 2
# Node: (_413:content {name: 'negative posts'}), Cumulative Degree: 2
# Node: (_414:media {name: 'site'}), Cumulative Degree: 2
# Node: (_417:group {name: 'american artist'}), Cumulative Degree: 2
# Node: (_423:medium {name: 'oral interviews'}), Cumulative Degree: 2
# Node: (_424:group {name: 'rural workers'}), Cumulative Degree: 2
# Node: (_431:media {name: 'photos'}), Cumulative Degree: 2
# Node: (_433:group {name: 'professional photographer'}), Cumulative Degree: 2
# Node: (_435:group {name: 'filmmakers'}), Cumulative Degree: 2
# Node: (_440:content {name: 'best practices'}), Cumulative Degree: 2
# Node: (_441:content {name: 'personal experiences'}), Cumulative Degree: 2
# Node: (_442:group {name: 'minister'}), Cumulative Degree: 2
# Node: (_447:group {name: 'hope collective'}), Cumulative Degree: 2
# Node: (_448:group {name: 'punk booking collective'}), Cumulative Degree: 2
# Node: (_451:medium {name: 'translation'}), Cumulative Degree: 2
# Node: (_456:group {name: 'decision maker'}), Cumulative Degree: 2
# Node: (_469:content {name: 'political treatise'}), Cumulative Degree: 2
# Node: (_474:group {name: 'defendant'}), Cumulative Degree: 2
# Node: (_485:medium {name: 'brochure'}), Cumulative Degree: 2
# Node: (_499:medium {name: 'puddling'}), Cumulative Degree: 2
# Node: (_502:group {name: 'elven archers'}), Cumulative Degree: 2
# Node: (_506:group {name: 'partners'}), Cumulative Degree: 2
# Node: (_507:group {name: 'additional members'}), Cumulative Degree: 2
# Node: (_508:medium {name: 'wikiring'}), Cumulative Degree: 2
# Node: (_509:content {name: 'shared resources'}), Cumulative Degree: 2
# Node: (_520:medium {name: 'ultimatum games'}), Cumulative Degree: 2
# Node: (_521:content {name: 'attitudinal questions'}), Cumulative Degree: 2
# Node: (_523:content {name: 'rare books'}), Cumulative Degree: 2
# Node: (_527:group {name: 'bottlenose dolphins'}), Cumulative Degree: 2
# Node: (_530:medium {name: 'records'}), Cumulative Degree: 2
# Node: (_539:group {name: 'savages'}), Cumulative Degree: 2
# Node: (_542:medium {name: 'weekly epistles'}), Cumulative Degree: 2
# Node: (_548:group {name: 'creeps'}), Cumulative Degree: 2
# Node: (_549:group {name: 'thugs'}), Cumulative Degree: 2
# Node: (_550:group {name: 'demons'}), Cumulative Degree: 2
# Node: (_551:group {name: 'monsters'}), Cumulative Degree: 2
# Node: (_552:group {name: 'fetid creatures'}), Cumulative Degree: 2
# Node: (_553:group {name: 'vermin'}), Cumulative Degree: 2
# Node: (_555:group {name: 'misfits'}), Cumulative Degree: 2
# Node: (_568:group {name: 'blogger'}), Cumulative Degree: 2
# Node: (_570:group {name: 'original poster'}), Cumulative Degree: 2
# Node: (_571:media {name: 'technology and society magazine'}), Cumulative Degree: 2
# Node: (_576:medium {name: 'mix'}), Cumulative Degree: 2
# Node: (_579:group {name: 'forces of mass-commercialization'}), Cumulative Degree: 2
# Node: (_580:medium {name: 'forum'}), Cumulative Degree: 2
# Node: (_584:group {name: 'argument'}), Cumulative Degree: 2
# Node: (_591:group {name: 'controversy'}), Cumulative Degree: 2
# Node: (_593:content {name: 'titles'}), Cumulative Degree: 2
# Node: (_594:medium {name: 'investigation'}), Cumulative Degree: 2
# Node: (_603:content {name: 'form'}), Cumulative Degree: 2
# Node: (_606:content {name: 'matter'}), Cumulative Degree: 2
# Node: (_611:medium {name: '2006 robin hood series'}), Cumulative Degree: 2
# Node: (_617:group {name: 'celtic'}), Cumulative Degree: 2
# Node: (_618:medium {name: 'seminars'}), Cumulative Degree: 2
# Node: (_620:group {name: 'organisations'}), Cumulative Degree: 2
# Node: (_621:medium {name: 'symposia'}), Cumulative Degree: 2
# Node: (_622:group {name: 'alumni'}), Cumulative Degree: 2
# Node: (_623:group {name: 'government'}), Cumulative Degree: 2
# Node: (_645:content {name: 'book reviews'}), Cumulative Degree: 2
# Node: (_647:group {name: 'namesake'}), Cumulative Degree: 2
# Node: (_648:media {name: '1990 film'}), Cumulative Degree: 2
# Node: (_655:group {name: 'association'}), Cumulative Degree: 2
# Node: (_670:group {name: 'sweet friend'}), Cumulative Degree: 2
# Node: (_675:media {name: 'mortal kombat'}), Cumulative Degree: 2
# Node: (_677:group {name: 'secretariat'}), Cumulative Degree: 2
# Node: (_687:group {name: 'x-men'}), Cumulative Degree: 2
# Node: (_688:group {name: 'sentinels'}), Cumulative Degree: 2
# Node: (_689:content {name: 'clip'}), Cumulative Degree: 2
# Node: (_690:medium {name: 'animated series'}), Cumulative Degree: 2
# Node: (_691:group {name: 'party-goers'}), Cumulative Degree: 2
# Node: (_694:group {name: 'principal'}), Cumulative Degree: 2
# Node: (_700:medium {name: 'letter'}), Cumulative Degree: 2
# Node: (_704:group {name: 'grandmother'}), Cumulative Degree: 2
# Node: (_707:group {name: 'amish community'}), Cumulative Degree: 2
# Node: (_713:group {name: 'fabs'}), Cumulative Degree: 2
# Node: (_728:group {name: 'council'}), Cumulative Degree: 2
# Node: (_749:content {name: 'analytical articles'}), Cumulative Degree: 2
# Node: (_750:content {name: 'statistics'}), Cumulative Degree: 2
# Node: (_751:content {name: 'projections'}), Cumulative Degree: 2
# Node: (_756:group {name: 'other sources'}), Cumulative Degree: 2
# Node: (_757:medium {name: 'questionnaire'}), Cumulative Degree: 2
# Node: (_758:content {name: 'budget information'}), Cumulative Degree: 2
# Node: (_768:content {name: 'entries'}), Cumulative Degree: 2
# Node: (_786:group {name: 'police chief'}), Cumulative Degree: 2
# Node: (_789:media {name: 'modern series'}), Cumulative Degree: 2
# Node: (_797:medium {name: 'press conferences'}), Cumulative Degree: 2
# Node: (_803:group {name: 'islanders'}), Cumulative Degree: 2
# Node: (_805:medium {name: 'fiction'}), Cumulative Degree: 2
# Node: (_807:content {name: 'humor'}), Cumulative Degree: 2
# Node: (_824:group {name: 'states'}), Cumulative Degree: 2
# Node: (_826:medium {name: 'water'}), Cumulative Degree: 2
# Node: (_827:content {name: 'commentary track'}), Cumulative Degree: 2
# Node: (_829:group {name: 'jury'}), Cumulative Degree: 2
# Node: (_834:group {name: 'tree roots'}), Cumulative Degree: 2
# Node: (_837:media {name: 'screen'}), Cumulative Degree: 2
# Node: (_840:medium {name: 'newspapers'}), Cumulative Degree: 2
# Node: (_841:content {name: 'volume'}), Cumulative Degree: 2
# Node: (_843:group {name: 'classical age'}), Cumulative Degree: 2
# Node: (_844:media {name: 'reservation newspaper'}), Cumulative Degree: 2
# Node: (_845:content {name: 'headline'}), Cumulative Degree: 2
# Node: (_846:group {name: 'wilma mankiller'}), Cumulative Degree: 2
# Node: (_847:group {name: 'cecelia babykiller'}), Cumulative Degree: 2
# Node: (_872:group {name: 'aardvarks'}), Cumulative Degree: 2
# Node: (_876:group {name: 'recommendations'}), Cumulative Degree: 2
# Node: (_879:medium {name: 'world war ii'}), Cumulative Degree: 2
# Node: (_884:media {name: 'file photo'}), Cumulative Degree: 2
# Node: (_894:content {name: 'facts'}), Cumulative Degree: 2
# Node: (_897:group {name: 'technology writer'}), Cumulative Degree: 2
# Node: (_909:content {name: 'political speech'}), Cumulative Degree: 2
# Node: (_916:group {name: 'miro'}), Cumulative Degree: 2
# Node: (_923:medium {name: 'broadcast television'}), Cumulative Degree: 2
# Node: (_932:medium {name: 'chivalric novels'}), Cumulative Degree: 2
# Node: (_943:medium {name: 'maori'}), Cumulative Degree: 2
# Node: (_944:group {name: 'population groups'}), Cumulative Degree: 2
# Node: (_945:medium {name: 'bill'}), Cumulative Degree: 2
# Node: (_948:group {name: 'editor'}), Cumulative Degree: 2
# Node: (_950:group {name: 'hobo'}), Cumulative Degree: 2
# Node: (_951:group {name: 'dick'}), Cumulative Degree: 2
# Node: (_952:content {name: 'knife'}), Cumulative Degree: 2
# Node: (_956:group {name: 'writers'}), Cumulative Degree: 2
# Node: (_959:group {name: 'critics'}), Cumulative Degree: 2
# Node: (_971:group {name: 'president'}), Cumulative Degree: 2
# Node: (_972:medium {name: 'democratic nomination'}), Cumulative Degree: 2
# Node: (_977:medium {name: 'manuscript'}), Cumulative Degree: 2
# Node: (_980:group {name: 'librarian'}), Cumulative Degree: 2
# Node: (_985:content {name: 'emotional virus'}), Cumulative Degree: 2
# Node: (_987:group {name: 'restaurant chefs'}), Cumulative Degree: 2
# Node: (_989:group {name: 'monk'}), Cumulative Degree: 2
# Node: (_990:group {name: 'cookbook author'}), Cumulative Degree: 2
# Node: (_991:group {name: 'star'}), Cumulative Degree: 2
# Node: (_993:group {name: 'contestants'}), Cumulative Degree: 2
# Node: (_997:group {name: 'accounting department'}), Cumulative Degree: 2
# Node: (_1000:medium {name: 'streaking'}), Cumulative Degree: 2
# Node: (_1013:group {name: 'church'}), Cumulative Degree: 2
# Node: (_1015:group {name: 'builder'}), Cumulative Degree: 2
# Node: (_1018:medium {name: 'italian championship'}), Cumulative Degree: 2
# Node: (_1019:group {name: 'horses'}), Cumulative Degree: 2
# Node: (_1021:medium {name: 'printer'}), Cumulative Degree: 2
# Node: (_1028:medium {name: 'reviews'}), Cumulative Degree: 2
# Node: (_1030:media {name: 'charts'}), Cumulative Degree: 2
# Node: (_1032:group {name: 'rankin/bass'}), Cumulative Degree: 2
# Node: (_1035:content {name: 'abortion'}), Cumulative Degree: 2
# Node: (_1042:content {name: 'communication'}), Cumulative Degree: 2
# Node: (_1058:group {name: 'herts advertiser'}), Cumulative Degree: 2
# Node: (_1059:medium {name: 'cinema'}), Cumulative Degree: 2
# Node: (_1065:group {name: 'passengers'}), Cumulative Degree: 2
# Node: (_1074:medium {name: 'light'}), Cumulative Degree: 2
# Node: (_1075:medium {name: 'fiber'}), Cumulative Degree: 2
# Node: (_1080:medium {name: 'countdown'}), Cumulative Degree: 2
# Node: (_1089:content {name: 'personal information'}), Cumulative Degree: 2
# Node: (_1094:group {name: 'protagonist'}), Cumulative Degree: 2
# Node: (_1097:group {name: 'atoms'}), Cumulative Degree: 2
# Node: (_1114:group {name: 'john'}), Cumulative Degree: 2
# Node: (_1120:medium {name: 'krakatau explosion'}), Cumulative Degree: 2
# Node: (_1124:group {name: 'facilitator'}), Cumulative Degree: 2
# Node: (_1125:content {name: 'written record'}), Cumulative Degree: 2
# Node: (_1127:content {name: 'recommendations'}), Cumulative Degree: 2
# Node: (_1129:content {name: 'background'}), Cumulative Degree: 2
# Node: (_1134:medium {name: 'wbai'}), Cumulative Degree: 2
# Node: (_1135:medium {name: 'streaming'}), Cumulative Degree: 2
# Node: (_1138:medium {name: 'telepresence'}), Cumulative Degree: 2
# Node: (_1141:medium {name: 'propaganda'}), Cumulative Degree: 2
# Node: (_1143:group {name: 'hermit'}), Cumulative Degree: 2
# Node: (_1179:content {name: 'dianetics'}), Cumulative Degree: 2
# Node: (_1180:content {name: 'instructions'}), Cumulative Degree: 2
# Node: (_1181:content {name: 'method'}), Cumulative Degree: 2
# Node: (_1184:group {name: 'hugo'}), Cumulative Degree: 2
# Node: (_1189:group {name: 'experimenter'}), Cumulative Degree: 2
# Node: (_1190:group {name: 'infant'}), Cumulative Degree: 2
# Node: (_1191:content {name: 'visual fixations'}), Cumulative Degree: 2
# Node: (_1192:content {name: 'stimuli'}), Cumulative Degree: 2
# Node: (_1197:media {name: 'new york times'}), Cumulative Degree: 2
# Node: (_1201:medium {name: 'fax'}), Cumulative Degree: 2
# Node: (_1202:medium {name: 'text message'}), Cumulative Degree: 2
# Node: (_1219:group {name: 'adolescent'}), Cumulative Degree: 2
# Node: (_1222:group {name: 'cook'}), Cumulative Degree: 2
# Node: (_1223:group {name: 'dinner'}), Cumulative Degree: 2
# Node: (_1247:medium {name: 'comedy'}), Cumulative Degree: 2
# Node: (_1250:media {name: 'photographs'}), Cumulative Degree: 2
# Node: (_1254:group {name: 'conflicts'}), Cumulative Degree: 2
# Node: (_1257:group {name: 'subject'}), Cumulative Degree: 2
# Node: (_1259:medium {name: 'hurricanes'}), Cumulative Degree: 2
# Node: (_1264:group {name: 'bees'}), Cumulative Degree: 2
# Node: (_1279:group {name: 'clinicians'}), Cumulative Degree: 2
# Node: (_1282:medium {name: 'a capella'}), Cumulative Degree: 2
# Node: (_1283:content {name: 'national anthem'}), Cumulative Degree: 2
# Node: (_1284:group {name: 'south african'}), Cumulative Degree: 2
# Node: (_1290:group {name: 'drivers'}), Cumulative Degree: 2
# Node: (_1291:medium {name: 'adm scandal'}), Cumulative Degree: 2
# Node: (_1296:content {name: 'laughter'}), Cumulative Degree: 2
# Node: (_1298:medium {name: 'narrow-band speech'}), Cumulative Degree: 2
# Node: (_1303:group {name: 'master humorist'}), Cumulative Degree: 2
# Node: (_1313:content {name: 'note'}), Cumulative Degree: 2
# Node: (_1317:group {name: 'corpses'}), Cumulative Degree: 2
# Node: (_1326:group {name: 'manager'}), Cumulative Degree: 2
# Node: (_1330:media {name: 'capsule'}), Cumulative Degree: 2
# Node: (_1331:medium {name: 'message tube'}), Cumulative Degree: 2
# Node: (_1340:content {name: 'key documents'}), Cumulative Degree: 2
# Node: (_1349:medium {name: 'emails'}), Cumulative Degree: 2
# Node: (_1361:medium {name: 'wind'}), Cumulative Degree: 2
# Node: (_1370:medium {name: 'wax paper'}), Cumulative Degree: 2
# Node: (_1380:media {name: 'exeretonevra'}), Cumulative Degree: 2
# Node: (_1395:group {name: 'congress'}), Cumulative Degree: 2
# Node: (_1398:group {name: 'love'}), Cumulative Degree: 2
# Node: (_1399:content {name: 'confetti hearts'}), Cumulative Degree: 2
# Node: (_1400:group {name: 'sweetheart'}), Cumulative Degree: 2
# Node: (_1426:content {name: 'plays'}), Cumulative Degree: 2
# Node: (_1427:group {name: 'shakespeare'}), Cumulative Degree: 2
# Node: (_1428:group {name: 'citizens'}), Cumulative Degree: 2
# Node: (_1429:medium {name: 'government proclamations'}), Cumulative Degree: 2
# Node: (_1440:group {name: 'ethics'}), Cumulative Degree: 2
# Node: (_1445:group {name: 'institutional'}), Cumulative Degree: 2
# Node: (_1457:medium {name: 'work'}), Cumulative Degree: 2
# Node: (_1473:medium {name: 'new age retreat'}), Cumulative Degree: 2
# Node: (_1478:group {name: 'real-life people'}), Cumulative Degree: 2
# Node: (_1482:medium {name: 'script'}), Cumulative Degree: 2
# Node: (_1485:group {name: 'fellows'}), Cumulative Degree: 2
# Node: (_1493:group {name: 'race relations'}), Cumulative Degree: 2
# Node: (_1494:group {name: 'urban crime'}), Cumulative Degree: 2
# Node: (_1495:group {name: 'poverty'}), Cumulative Degree: 2
# Node: (_1506:medium {name: 'action films'}), Cumulative Degree: 2
# Node: (_1520:group {name: 'main character'}), Cumulative Degree: 2
# Node: (_1522:group {name: 'maritime history'}), Cumulative Degree: 2
# Node: (_1524:group {name: 'south american'}), Cumulative Degree: 2
# Node: (_1527:group {name: 'lesser known artists'}), Cumulative Degree: 2
# Node: (_1531:group {name: 'air police'}), Cumulative Degree: 2
# Node: (_1536:media {name: 'films'}), Cumulative Degree: 2
# Node: (_1546:group {name: 'politicians'}), Cumulative Degree: 2
# Node: (_1547:group {name: 'authority figures'}), Cumulative Degree: 2
# Node: (_1548:group {name: 'irishmen'}), Cumulative Degree: 2
# Node: (_1559:content {name: 'correspondence'}), Cumulative Degree: 2
# Node: (_1562:group {name: 'life'}), Cumulative Degree: 2
# Node: (_1566:medium {name: 'publications'}), Cumulative Degree: 2
# Node: (_1576:medium {name: 'ems'}), Cumulative Degree: 2
# Node: (_1580:medium {name: 'parodies'}), Cumulative Degree: 2
# Node: (_1581:group {name: 'schools'}), Cumulative Degree: 2
# Node: (_1582:group {name: 'health authorities'}), Cumulative Degree: 2
# Node: (_1593:media {name: 'journals'}), Cumulative Degree: 2
# Node: (_1594:group {name: 'birding'}), Cumulative Degree: 2
# Node: (_1595:group {name: 'ornithology'}), Cumulative Degree: 2
# Node: (_1605:medium {name: 'chinese fable'}), Cumulative Degree: 2
# Node: (_1609:medium {name: 'images'}), Cumulative Degree: 2
# Node: (_1615:content {name: 'writings'}), Cumulative Degree: 2
# Node: (_1624:group {name: 'doping world'}), Cumulative Degree: 2
# Node: (_1625:media {name: 'hakani'}), Cumulative Degree: 2
# Node: (_1639:group {name: 'contemporaries'}), Cumulative Degree: 2
# Node: (_1648:medium {name: 'pottery'}), Cumulative Degree: 2
# Node: (_1655:content {name: 'quotation'}), Cumulative Degree: 2
# Node: (_1656:content {name: 'claim'}), Cumulative Degree: 2
# Node: (_1664:group {name: 'eastwood'}), Cumulative Degree: 2
# Node: (_1665:medium {name: 'films'}), Cumulative Degree: 2
# Node: (_1671:group {name: 'progenitor'}), Cumulative Degree: 2
# Node: (_1673:content {name: 'murder'}), Cumulative Degree: 2
# Node: (_1674:group {name: 'tribe'}), Cumulative Degree: 2
# Node: (_1675:group {name: 'bad monkeys'}), Cumulative Degree: 2
# Node: (_1676:group {name: 'riders'}), Cumulative Degree: 2
# Node: (_1677:group {name: 'peloton'}), Cumulative Degree: 2
# Node: (_1678:medium {name: 'articles'}), Cumulative Degree: 2
# Node: (_1688:group {name: 'italian craftsman'}), Cumulative Degree: 2
# Node: (_1697:group {name: 'second author'}), Cumulative Degree: 2
# Node: (_1701:group {name: 'quizmaster'}), Cumulative Degree: 2
# Node: (_1702:content {name: 'riddle'}), Cumulative Degree: 2
# Node: (_1708:medium {name: 'jazz'}), Cumulative Degree: 2
# Node: (_1713:content {name: '33-page introductory essay'}), Cumulative Degree: 2
# Node: (_1716:group {name: 'highland pipers'}), Cumulative Degree: 2
# Node: (_1718:medium {name: 'lord of the rings'}), Cumulative Degree: 2
# Node: (_1723:group {name: 'complaints'}), Cumulative Degree: 2
# Node: (_1727:medium {name: 'nonfiction book'}), Cumulative Degree: 2
# Node: (_1735:media {name: 'television pictures'}), Cumulative Degree: 2
# Node: (_1741:group {name: 'soloist'}), Cumulative Degree: 2
# Node: (_1746:medium {name: 'scholarship'}), Cumulative Degree: 2
# Node: (_1747:group {name: 'committee'}), Cumulative Degree: 2
# Node: (_1754:group {name: 'discoverer'}), Cumulative Degree: 2
# Node: (_1791:group {name: 'sandhill cranes'}), Cumulative Degree: 2
# Node: (_1796:content {name: 'cover story'}), Cumulative Degree: 2
# ...
# Node: (_2321:content {name: 'indexing vocabulary'}), Cumulative Degree: 1
# Node: (_2322:group {name: 'knights'}), Cumulative Degree: 1
# Node: (_2323:content {name: 'dragon divide'}), Cumulative Degree: 1
# Node: (_2324:medium {name: 'charcoal'}), Cumulative Degree: 1
# Node: (_2326:group {name: 'robert harris'}), Cumulative Degree: 1
# Node: (_2327:group {name: 'romani'}), Cumulative Degree: 1
# Node: (_2328:group {name: 'gypsy'}), Cumulative Degree: 1
# Node: (_2329:medium {name: 'semi-structured interviews'}), Cumulative Degree: 1
# Node: (_2330:content {name: 'agent-informed account'}), Cumulative Degree: 1
# Node: (_2331:content {name: 'policy processes'}), Cumulative Degree: 1
# Node: (_2333:group {name: 'astronomers'}), Cumulative Degree: 1
# Node: (_2334:group {name: 'space scientists'}), Cumulative Degree: 1
# Node: (_2335:medium {name: 'marketing communications resources'}), Cumulative Degree: 1
# Node: (_2336:group {name: 'target audiences'}), Cumulative Degree: 1
# Node: (_2338:medium {name: 'licensing'}), Cumulative Degree: 1
# Node: (_2339:group {name: 'crane operator'}), Cumulative Degree: 1
# Node: (_2341:group {name: 'fisherman'}), Cumulative Degree: 1
# Node: (_2342:group {name: 'samurai'}), Cumulative Degree: 1
# Node: (_2343:group {name: 'opponents'}), Cumulative Degree: 1
# Node: (_2344:group {name: 'rider'}), Cumulative Degree: 1
# Node: (_2345:medium {name: 'mud-puddle'}), Cumulative Degree: 1
# Node: (_2346:group {name: '10 most beautiful women'}), Cumulative Degree: 1
# Node: (_2347:media {name: 'laser projections'}), Cumulative Degree: 1
# Node: (_2348:media {name: 'video screens'}), Cumulative Degree: 1
# Node: (_2349:content {name: 'black and white photographs'}), Cumulative Degree: 1
# Node: (_2350:group {name: 'lefevre'}), Cumulative Degree: 1
# Node: (_2351:medium {name: 'studio version'}), Cumulative Degree: 1
# Node: (_2352:group {name: 'ryan'}), Cumulative Degree: 1
# Node: (_2353:media {name: 'bullet'}), Cumulative Degree: 1
# Node: (_2355:media {name: 'hiphop'}), Cumulative Degree: 1
# Node: (_2356:group {name: 'consumer society'}), Cumulative Degree: 1
# Node: (_2357:group {name: 'orchestra'}), Cumulative Degree: 1
# Node: (_2358:group {name: 'russian'}), Cumulative Degree: 1
# Node: (_2359:group {name: 'choreographer'}), Cumulative Degree: 1
# Node: (_2360:media {name: 'hairspray'}), Cumulative Degree: 1
# Node: (_2361:medium {name: 'vitrified'}), Cumulative Degree: 1
# Node: (_2362:group {name: 'infertility population'}), Cumulative Degree: 1
# Node: (_2364:group {name: 'wealthy bachelor'}), Cumulative Degree: 1
# Node: (_2365:group {name: 'crew'}), Cumulative Degree: 1
# Node: (_2366:group {name: 'assembly operations'}), Cumulative Degree: 1
# Node: (_2368:group {name: 'murderer'}), Cumulative Degree: 1
# Node: (_2369:medium {name: 'black and white mosaic'}), Cumulative Degree: 1
# Node: (_2371:content {name: 'thoughtless statements'}), Cumulative Degree: 1
# Node: (_2372:group {name: 'professor'}), Cumulative Degree: 1
# Node: (_2377:medium {name: 'signoff queue'}), Cumulative Degree: 1
# Node: (_2378:group {name: 'libel claimant'}), Cumulative Degree: 1
# Node: (_2379:group {name: 'gay'}), Cumulative Degree: 1
# Node: (_2380:medium {name: "beggar'ss opera"}), Cumulative Degree: 1
# Node: (_2381:group {name: 'revellers'}), Cumulative Degree: 1
# Node: (_2382:medium {name: 'party mode'}), Cumulative Degree: 1
# Node: (_2383:group {name: "wolf 's dragoons"}), Cumulative Degree: 1
# Node: (_2385:group {name: 'mercenary regiment'}), Cumulative Degree: 1
# Node: (_2386:group {name: 'specialists'}), Cumulative Degree: 1
# Node: (_2387:group {name: 'fields'}), Cumulative Degree: 1
# Node: (_2388:content {name: 'external values'}), Cumulative Degree: 1
# Node: (_2389:group {name: 'museological thought'}), Cumulative Degree: 1
# Node: (_2390:group {name: 'court'}), Cumulative Degree: 1
# Node: (_2391:group {name: 'american citizen'}), Cumulative Degree: 1
# Node: (_2394:group {name: 'individual contributions'}), Cumulative Degree: 1
# Node: (_2395:group {name: 'coalitions'}), Cumulative Degree: 1
# Node: (_2396:group {name: 'coalition'}), Cumulative Degree: 1
# Node: (_2397:group {name: 'tories'}), Cumulative Degree: 1
# Node: (_2399:group {name: 'opposition parties'}), Cumulative Degree: 1
# Node: (_2400:content {name: 'homicide'}), Cumulative Degree: 1
# Node: (_2401:medium {name: 'disassembler'}), Cumulative Degree: 1
# Node: (_2402:group {name: 'commercial networks'}), Cumulative Degree: 1
# Node: (_2403:medium {name: 'high-definition broadcast'}), Cumulative Degree: 1
# Node: (_2404:group {name: 'councilor'}), Cumulative Degree: 1
# Node: (_2405:medium {name: 'infinitival'}), Cumulative Degree: 1
# Node: (_2406:medium {name: 'call'}), Cumulative Degree: 1
# Node: (_2407:content {name: 'abstract theme'}), Cumulative Degree: 1
# Node: (_2408:content {name: 'concrete imagery'}), Cumulative Degree: 1
# Node: (_2410:content {name: 'evidence'}), Cumulative Degree: 1
# Node: (_2411:group {name: 'politician'}), Cumulative Degree: 1
# Node: (_2412:medium {name: 'tourism'}), Cumulative Degree: 1
# Node: (_2413:content {name: 'actions'}), Cumulative Degree: 1
# Node: (_2414:media {name: 'bbc documentary'}), Cumulative Degree: 1
# Node: (_2416:group {name: 'organizations'}), Cumulative Degree: 1
# Node: (_2417:content {name: 'support'}), Cumulative Degree: 1
# Node: (_2418:content {name: 'burning bodies'}), Cumulative Degree: 1
# Node: (_2419:content {name: 'human remains'}), Cumulative Degree: 1
# Node: (_2420:content {name: 'explosion'}), Cumulative Degree: 1
# Node: (_2421:medium {name: 'pentagon crash'}), Cumulative Degree: 1
# Node: (_2422:group {name: 'organism'}), Cumulative Degree: 1
# Node: (_2423:group {name: 'hosts'}), Cumulative Degree: 1
# Node: (_2426:content {name: 'solute'}), Cumulative Degree: 1
# Node: (_2427:medium {name: 'beaker'}), Cumulative Degree: 1
# Node: (_2428:medium {name: 'glass flask'}), Cumulative Degree: 1
# Node: (_2430:group {name: 'immigrant flows'}), Cumulative Degree: 1
# Node: (_2431:medium {name: 'microsimulation'}), Cumulative Degree: 1
# Node: (_2432:medium {name: 'five bells'}), Cumulative Degree: 1
# Node: (_2433:group {name: 'poet union members'}), Cumulative Degree: 1
# Node: (_2434:medium {name: 'combat sar demo'}), Cumulative Degree: 1
# Node: (_2435:medium {name: 'technological advances'}), Cumulative Degree: 1
# Node: (_2436:group {name: 'wars'}), Cumulative Degree: 1
# Node: (_2437:medium {name: 'teleport'}), Cumulative Degree: 1
# Node: (_2439:group {name: 'bodies'}), Cumulative Degree: 1
# Node: (_2441:medium {name: 'wine'}), Cumulative Degree: 1
# Node: (_2442:medium {name: 'bacchus'}), Cumulative Degree: 1
# Node: (_2443:content {name: 'box'}), Cumulative Degree: 1
# Node: (_2444:content {name: 'memory'}), Cumulative Degree: 1
# Node: (_2446:content {name: 'odor'}), Cumulative Degree: 1
# Node: (_2447:content {name: 'detective story'}), Cumulative Degree: 1
# Node: (_2448:group {name: 'purchasers'}), Cumulative Degree: 1
# Node: (_2449:media {name: 'official charts'}), Cumulative Degree: 1
# Node: (_2450:group {name: 'ingo practitioners'}), Cumulative Degree: 1
# Node: (_2451:content {name: 'discourse'}), Cumulative Degree: 1
# Node: (_2452:medium {name: 'guide'}), Cumulative Degree: 1
# Node: (_2453:content {name: 'chapters'}), Cumulative Degree: 1
# Node: (_2454:medium {name: 'medieval latin manuscript'}), Cumulative Degree: 1
# Node: (_2455:group {name: 'isle of man'}), Cumulative Degree: 1
# Node: (_2456:medium {name: 'document repository'}), Cumulative Degree: 1
# Node: (_2457:content {name: 'archival documents'}), Cumulative Degree: 1
# Node: (_2464:group {name: 'forces of nature'}), Cumulative Degree: 1
# Node: (_2465:group {name: 'jesus'}), Cumulative Degree: 1
# Node: (_2466:group {name: 'disciples'}), Cumulative Degree: 1
# Node: (_2467:content {name: 'sport-related shows'}), Cumulative Degree: 1
# Node: (_2468:group {name: 'agencies'}), Cumulative Degree: 1
# Node: (_2470:content {name: 'summary'}), Cumulative Degree: 1
# Node: (_2471:content {name: 'important aspects'}), Cumulative Degree: 1
# Node: (_2472:content {name: 'subject'}), Cumulative Degree: 1
# Node: (_2473:group {name: 'nature'}), Cumulative Degree: 1
# Node: (_2474:group {name: 'members'}), Cumulative Degree: 1
# Node: (_2476:group {name: 'teenage girl'}), Cumulative Degree: 1
# Node: (_2477:group {name: 'son'}), Cumulative Degree: 1
# Node: (_2478:content {name: 'tales'}), Cumulative Degree: 1
# Node: (_2480:media {name: 'clip'}), Cumulative Degree: 1
# Node: (_2481:medium {name: 'fable'}), Cumulative Degree: 1
# Node: (_2482:group {name: 'married people'}), Cumulative Degree: 1
# Node: (_2483:medium {name: 'novels'}), Cumulative Degree: 1
# Node: (_2484:group {name: 'fictional secret agents'}), Cumulative Degree: 1
# Node: (_2485:group {name: 'nuclear family'}), Cumulative Degree: 1
# Node: (_2486:content {name: 'interview clips'}), Cumulative Degree: 1
# Node: (_2488:content {name: 'examination papers'}), Cumulative Degree: 1
# Node: (_2490:medium {name: 'survey'}), Cumulative Degree: 1
# Node: (_2491:medium {name: 'coloring'}), Cumulative Degree: 1
# Node: (_2492:content {name: 'textiles'}), Cumulative Degree: 1
# Node: (_2495:group {name: 'gender'}), Cumulative Degree: 1
# Node: (_2496:group {name: 'royal families'}), Cumulative Degree: 1
# Node: (_2497:medium {name: 'review'}), Cumulative Degree: 1
# Node: (_2502:content {name: 'allegations'}), Cumulative Degree: 1
# Node: (_2503:group {name: 'trend-setting clique'}), Cumulative Degree: 1
# Node: (_2505:content {name: 'literary artifact'}), Cumulative Degree: 1
# Node: (_2507:group {name: 'muslim world'}), Cumulative Degree: 1
# Node: (_2508:group {name: 'historical resources'}), Cumulative Degree: 1
# Node: (_2509:medium {name: 'picture book'}), Cumulative Degree: 1
# Node: (_2510:group {name: 'street writer'}), Cumulative Degree: 1
# Node: (_2512:group {name: 'addressees'}), Cumulative Degree: 1
# Node: (_2513:group {name: 'film critic'}), Cumulative Degree: 1
# Node: (_2514:group {name: 'louis'}), Cumulative Degree: 1
# Node: (_2515:medium {name: 'photographic plates'}), Cumulative Degree: 1
# Node: (_2516:content {name: 'chords'}), Cumulative Degree: 1
# Node: (_2518:content {name: 'anti-establishment broadsides'}), Cumulative Degree: 1
# Node: (_2519:group {name: 'claimant'}), Cumulative Degree: 1
# Node: (_2520:group {name: 'statesman'}), Cumulative Degree: 1
# Node: (_2521:group {name: 'positions'}), Cumulative Degree: 1
# Node: (_2522:group {name: 'chimpanzees'}), Cumulative Degree: 1
# Node: (_2523:medium {name: 'social displays'}), Cumulative Degree: 1
# Node: (_2524:group {name: 'brothers'}), Cumulative Degree: 1
# Node: (_2525:group {name: 'self-help industry'}), Cumulative Degree: 1
# Node: (_2528:group {name: 'application developer'}), Cumulative Degree: 1
# Node: (_2529:medium {name: 'blog posting'}), Cumulative Degree: 1
# Node: (_2531:medium {name: 'scissors'}), Cumulative Degree: 1
# Node: (_2532:medium {name: 'glue'}), Cumulative Degree: 1
# Node: (_2533:content {name: 'fragments'}), Cumulative Degree: 1
# Node: (_2536:medium {name: 'tools'}), Cumulative Degree: 1
# Node: (_2537:medium {name: 'entertainment'}), Cumulative Degree: 1
# Node: (_2538:medium {name: 'reviewing toolbar'}), Cumulative Degree: 1
# Node: (_2539:group {name: 'radical cleric'}), Cumulative Degree: 1
# Node: (_2540:medium {name: 'english-language web site'}), Cumulative Degree: 1
# Node: (_2541:medium {name: 'ballot'}), Cumulative Degree: 1
# Node: (_2542:group {name: 'national leaders'}), Cumulative Degree: 1
# Node: (_2544:group {name: 'social classes'}), Cumulative Degree: 1
# Node: (_2545:group {name: 'working class'}), Cumulative Degree: 1
# Node: (_2547:group {name: 'red baron flying ace'}), Cumulative Degree: 1
# Node: (_2548:group {name: 'vampire fighters'}), Cumulative Degree: 1
# Node: (_2549:group {name: 'syndicate of chicago capitalists'}), Cumulative Degree: 1
# Node: (_2550:group {name: 'master chefs'}), Cumulative Degree: 1
# Node: (_2552:content {name: 'philosophical work'}), Cumulative Degree: 1
# Node: (_2553:medium {name: 'scope'}), Cumulative Degree: 1
# Node: (_2554:group {name: 'butterflies'}), Cumulative Degree: 1
# Node: (_2555:group {name: 'b-17 flight personnel'}), Cumulative Degree: 1
# Node: (_2556:group {name: 'squadron'}), Cumulative Degree: 1
# Node: (_2557:group {name: 'bombers'}), Cumulative Degree: 1
# Node: (_2558:group {name: 'princess'}), Cumulative Degree: 1
# Node: (_2559:group {name: 'amazon women'}), Cumulative Degree: 1
# Node: (_2560:group {name: 'nazis'}), Cumulative Degree: 1
# Node: (_2561:medium {name: 'lawsuits'}), Cumulative Degree: 1
# Node: (_2566:group {name: 'epicurean'}), Cumulative Degree: 1
# Node: (_2567:group {name: 'anti-epicurean'}), Cumulative Degree: 1
# Node: (_2568:group {name: 'cars'}), Cumulative Degree: 1
# Node: (_2569:medium {name: 'upstream signal'}), Cumulative Degree: 1
# Node: (_2573:content {name: 'language'}), Cumulative Degree: 1
# Node: (_2574:medium {name: 'cross over'}), Cumulative Degree: 1
# Node: (_2575:group {name: 'forum goons'}), Cumulative Degree: 1
# Node: (_2576:content {name: 'products'}), Cumulative Degree: 1
# Node: (_2578:media {name: 'web'}), Cumulative Degree: 1
# Node: (_2579:content {name: 'political commentary'}), Cumulative Degree: 1
# Node: (_2580:group {name: 'communal divide'}), Cumulative Degree: 1
# Node: (_2581:medium {name: 'weather'}), Cumulative Degree: 1
# Node: (_2582:media {name: 'videotape'}), Cumulative Degree: 1
# Node: (_2583:media {name: 'galleries'}), Cumulative Degree: 1
# Node: (_2585:content {name: 'factual account'}), Cumulative Degree: 1
# Node: (_2586:group {name: 'catfish'}), Cumulative Degree: 1
# Node: (_2587:medium {name: 'heptachlor'}), Cumulative Degree: 1
# Node: (_2588:group {name: 'prophet'}), Cumulative Degree: 1
# Node: (_2589:medium {name: 'biographies'}), Cumulative Degree: 1
# Node: (_2590:media {name: 'record'}), Cumulative Degree: 1
# Node: (_2591:group {name: 'bisexuality'}), Cumulative Degree: 1
# Node: (_2592:content {name: 'full-page color photos'}), Cumulative Degree: 1
# Node: (_2593:content {name: 'word list'}), Cumulative Degree: 1
# Node: (_2595:content {name: 'parodies'}), Cumulative Degree: 1
# Node: (_2596:medium {name: 'live'}), Cumulative Degree: 1
# Node: (_2597:group {name: 'ospreys'}), Cumulative Degree: 1
# Node: (_2598:content {name: 'amendment'}), Cumulative Degree: 1
# Node: (_2599:content {name: 'semicolon'}), Cumulative Degree: 1
# Node: (_2600:content {name: 'religious exemption portion'}), Cumulative Degree: 1
# Node: (_2601:content {name: 'comma'}), Cumulative Degree: 1
# Node: (_2605:group {name: 'technician'}), Cumulative Degree: 1
# Node: (_2606:group {name: 'indian missions'}), Cumulative Degree: 1
# Node: (_2608:content {name: 'recepies'}), Cumulative Degree: 1
# Node: (_2609:group {name: 'danish academic'}), Cumulative Degree: 1
# Node: (_2610:media {name: 'fiction'}), Cumulative Degree: 1
# Node: (_2611:content {name: 'software program'}), Cumulative Degree: 1
# Node: (_2613:medium {name: 'universe'}), Cumulative Degree: 1
# Node: (_2615:group {name: 'quartet'}), Cumulative Degree: 1
# Node: (_2616:content {name: 'wedding song'}), Cumulative Degree: 1
# Node: (_2617:group {name: 'religious establishment'}), Cumulative Degree: 1
# Node: (_2619:group {name: 'alchemists'}), Cumulative Degree: 1
# Node: (_2620:media {name: 'dvd'}), Cumulative Degree: 1
# Node: (_2624:content {name: 'violence'}), Cumulative Degree: 1
# Node: (_381:content {name: 'film content'}), Cumulative Degree: 0
# Node: (_632:content {name: 'timers'}), Cumulative Degree: 0
# Node: (_716:content {name: 'writing'}), Cumulative Degree: 0
# Node: (_717:content {name: 'label'}), Cumulative Degree: 0
# Node: (_718:content {name: 'substance'}), Cumulative Degree: 0
# Node: (_719:content {name: 'hamburger mustard'}), Cumulative Degree: 0
# Node: (_1251:content {name: 'devastations'}), Cumulative Degree: 0
# Node: (_1412:content {name: 'header'}), Cumulative Degree: 0
# Node: (_1483:content {name: 'pictographic signs'}), Cumulative Degree: 0
# Node: (_2028:content {name: 'evaluation copy'}), Cumulative Degree: 0
# Node: (_2295:content {name: 'resource information sheets'}), Cumulative Degree: 0
# Node: (_2296:content {name: 'presentations'}), Cumulative Degree: 0
# Nodes sorted by cumulative degrees successfully.

# %%
total_nodes_query = "MATCH (n) RETURN COUNT(n) AS TotalNodes"
total_nodes = graph.run(total_nodes_query)
total_nodes
# for record in total_nodes:
#     print(record)
# Out:
#  TotalNodes
# ------------
#        2623

# %%
query = """
MATCH (n)
WITH labels(n) AS lbl, COUNT(n) AS cnt
RETURN lbl AS Label, cnt AS Count
ORDER BY Count DESC
"""

# Run the query
result = graph.run(query).data()

# Print the results
print("Total Entities by Entity Type:")
for record in result:
    labels = record['Label']
    count = record['Count']
    labels_str = ', '.join(labels)
    print(f"Label(s): {labels_str}, Count: {count}")
# Out:
# Total Entities by Entity Type:
# Label(s): group, Count: 1215
# Label(s): medium, Count: 611
# Label(s): content, Count: 586
# Label(s): media, Count: 211

# %%
# Total number of nodes
total_nodes_query = "MATCH (n) RETURN COUNT(n) AS TotalNodes"
total_nodes = graph.run(total_nodes_query).evaluate()

# Total number of relationships
total_relationships_query = "MATCH ()-[r]->() RETURN COUNT(r) AS TotalRelationships"
total_relationships = graph.run(total_relationships_query).evaluate()

print(f"Total Nodes: {total_nodes}")
print(f"Total Relationships: {total_relationships}")
# Out:
# Total Nodes: 2623
# Total Relationships: 2436

# %%
average_in_degree_query = """
MATCH (n)
OPTIONAL MATCH ()-[r]->(n)
WITH n, COUNT(r) AS InDegree
RETURN AVG(InDegree) AS AverageInDegree
"""
average_in_degree = graph.run(average_in_degree_query).evaluate()

average_out_degree_query = """
MATCH (n)
OPTIONAL MATCH (n)-[r]->()
WITH n, COUNT(r) AS OutDegree
RETURN AVG(OutDegree) AS AverageOutDegree
"""
average_out_degree = graph.run(average_out_degree_query).evaluate()
print(average_in_degree)
print(average_out_degree)
# Out:
# 0.9287075867327474
# 0.928707586732749

# %% [markdown]
# ### 5. The Question: #bu tong mei jie dui butong qunti de xi yin li

# %%
#the most distributed medium
query = """
MATCH (m:medium)-[r:isDistributedto]-()  // Adjust 'USES' to the actual relationship type
RETURN m.name AS Medium, COUNT(r) AS RelationshipCount
ORDER BY RelationshipCount DESC;
"""

# Run the query
results = graph.run(query)

results
# Out:
#  Medium  | RelationshipCount
# ---------|-------------------
#  book    |                60
#  article |                15
#  film    |                12

# %% [markdown]
# #### Example 1: what groups are books distributed to?

# %% [markdown]
# #### Example 2: what groups are articles distributed to?

# %%
query = """
MATCH (m:medium {name: "book"})-[:isDistributedto]->(g:group)
RETURN m, g.name
"""

# Run the query
results = graph.run(query)

# Print the results
for result in results:
    print(f"Medium: {result['m']['name']}, Group: {result['g.name']}")
# Out:
# Medium: book, Group: professional scribe
# Medium: book, Group: young readers
# Medium: book, Group: bisexuality
# Medium: book, Group: artists ' book simply means a book made by an artist
# Medium: book, Group: women
# Medium: book, Group: men
# Medium: book, Group: household
# Medium: book, Group: nuclear family
# Medium: book, Group: popular minister
# Medium: book, Group: programmers
# Medium: book, Group: muhammad
# Medium: book, Group: us
# Medium: book, Group: yemen
# Medium: book, Group: human rights
# Medium: book, Group: politics
# Medium: book, Group: teaching
# Medium: book, Group: learning
# Medium: book, Group: students
# Medium: book, Group: faculty
# Medium: book, Group: religion
# Medium: book, Group: dutch emigration
# Medium: book, Group: student
# Medium: book, Group: rural workers
# Medium: book, Group: allies
# Medium: book, Group: primary school teacher
# Medium: book, Group: class
# Medium: book, Group: reader
# Medium: book, Group: bacteria
# Medium: book, Group: fungi
# Medium: book, Group: parasites
# Medium: book, Group: protozoa
# Medium: book, Group: viruses
# Medium: book, Group: police chief
# Medium: book, Group: arnie gibbons
# Medium: book, Group: reviewer
# Medium: book, Group: librarian
# Medium: book, Group: people
# Medium: book, Group: practitioners
# Medium: book, Group: leading experts
# Medium: book, Group: ethics
# Medium: book, Group: justice
# Medium: book, Group: human
# Medium: book, Group: horses
# Medium: book, Group: wolves
# Medium: book, Group: sheep herders
# Medium: book, Group: pasture dwellers
# Medium: book, Group: everyone
# Medium: book, Group: directors
# Medium: book, Group: painter
# Medium: book, Group: school of fish
# Medium: book, Group: developer
# Medium: book, Group: cooperatives
# Medium: book, Group: vietnam veteran
# Medium: book, Group: death-march survivor
# Medium: book, Group: unc-chapel hill graduate
# Medium: book, Group: customers
# Medium: book, Group: american woman
# Medium: book, Group: unknown author
# Medium: book, Group: coptic egyptian poet
# Medium: book, Group: communities

# %% [markdown]
# #### Example 2: what groups are articles distributed to?

# %%
query = """
MATCH (m:medium {name: "article"})-[:isDistributedto]->(g:group)
RETURN m, g.name
"""

# Run the query
results = graph.run(query)

# Print the results
for result in results:
    print(f"Medium: {result['m']['name']}, Group: {result['g.name']}")
# Out:
# Medium: article, Group: turkic peoples
# Medium: article, Group: fish
# Medium: article, Group: families
# Medium: article, Group: women
# Medium: article, Group: feminist
# Medium: article, Group: patient
# Medium: article, Group: insubres
# Medium: article, Group: conflicts
# Medium: article, Group: switchboard operator
# Medium: article, Group: baseball player
# Medium: article, Group: early years workers
# Medium: article, Group: parents
# Medium: article, Group: pre-school children
# Medium: article, Group: small pharmacy chains
# Medium: article, Group: authors

# %% [markdown]
# #### Example 3: what groups are film distributed to?

# %%
query = """
MATCH (m:medium {name: "film"})-[:isDistributedto]->(g:group)
RETURN m, g.name
"""

# Run the query
results = graph.run(query)

# Print the results
for result in results:
    print(f"Medium: {result['m']['name']}, Group: {result['g.name']}")
# Out:
# Medium: film, Group: critics
# Medium: film, Group: directors
# Medium: film, Group: contemporary philosophers
# Medium: film, Group: racketeering
# Medium: film, Group: trade unionism
# Medium: film, Group: people
# Medium: film, Group: peers
# Medium: film, Group: friends
# Medium: film, Group: thompson
# Medium: film, Group: severine
# Medium: film, Group: class
# Medium: film, Group: cadaver

# %%
#https://neo4j.com/docs/graph-data-science/current/algorithms/betweenness-centrality/#
